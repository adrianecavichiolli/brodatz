# %%
import numpy as np

from brodatz.data_utils import process_file, process_file_some_classes, read_some_classes, save_model, read_train_test_sets, save_history
from brodatz.utils import probas_to_classes, accuracy, curr_date
from brodatz.visualization_utils import plot_image, plot, plot_history, plot_confusion_matrix, plot_inputs

from brodatz.models.keras_neural_net import KerasNeuralNetwork

from brodatz.brodatz_generator import *
from brodatz.brodatz_multicore_generator import *

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

from keras import regularizers, optimizers, utils
from keras.preprocessing.image import ImageDataGenerator
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())

import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# remove prefixes
import os
path = '/mnt/82db778e-0496-450c-9b25-d1e50a90e476/data/data4stas/01_data_cls'
os.chdir(path)

# %%
classes_range = np.arange(0, 20)
X_train, y_train, num_classes = process_file_some_classes('Alexander_cls_train.csv', classes_range)

# %%
classes_range = np.arange(0, 20)
X_train, y_train, num_classes = read_some_classes('Alexander_cls_train.csv', classes_range)

# %%
plot_image(X_mean)

# %%
plot_image(X_train[10])

# %%
classes_range = np.arange(0, 20)
X_train, y_train, num_classes = read_some_classes('Alexander_cls_train.csv', classes_range)
X_test, y_test, num_classes = read_some_classes('Alexander_cls_test.csv', classes_range)

X_train = X_train.astype('float') / 255
X_mean = np.mean(X_train, axis=0)
# X_std = np.std(X_train, axis=0)
# X_train = (X_train - X_mean) / (X_std + 1e-7)
X_train -= X_mean

X_test = X_test.astype('float') / 255
# X_test = (X_test - X_mean) / (X_std + 1e-7)
X_test -= X_mean
X_test = X_test[..., np.newaxis]

y_train = utils.to_categorical(y_train, num_classes=num_classes)
X_train = X_train[..., np.newaxis]

mask = np.random.permutation(len(X_test))
# X_train = X_train[mask]
# y_train = y_train[mask]
num_train = round(len(X_test) * 0.8)
X_val = X_test[num_train:]
y_val = y_test[num_train:]
y_val = utils.to_categorical(y_val, num_classes=num_classes)

# num_train = round(len(X_train) * 0.8)
# X_val = X_train[num_train:]
# y_val = y_train[num_train:]
# X_train = X_train[:num_train]
# y_train = y_train[:num_train]

# %%
train_filename = 'Alexander_cls_train.csv'
test_filenames = ['Alexander_cls_test.csv',
                  'Alexander_cls_test1.csv',
                  'Alexander_cls_test2.csv',
                  'Alexander_cls_test3.csv',
                  'Alexander_cls_test4.csv']
classes_range = np.arange(0, 111)
X_train, y_train, num_classes, X_val, y_val, test_list = read_train_test_sets(train_filename, test_filenames, classes_range)

# %%
class_number = 5
mask = np.argmax(y_train, axis=1) == class_number
X_train_cls = X_train[mask]

test_list_cls = [test[0][np.argmax(test[1], axis=1) == class_number] for test in test_list]
test_list_cls = [X_train_cls] + test_list_cls[1:]

# %%
plot_inputs(test_list_cls)

# %%
X_val, y_val = test_list[0][:2]

# %%
X_val.shape

# %%
import json
import pandas as pd
import datetime

def try_args(rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode,
             batch_size, epochs, learning_rate, regularization_strength):
    input_shape = X_train[0].shape
    
    learning_rate = learning_rate
    regularizer = regularizers.l2(regularization_strength)
    optimizer = optimizers.SGD(lr=learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
#     optimizer = optimizers.Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

   
    net = KerasNeuralNetwork(input_shape, num_classes, regularizer=regularizer, optimizer=optimizer)
    net.compile_model_9()
    
    datagen = ImageDataGenerator(
        rotation_range=rotation_range,
        shear_range=np.pi * shear_range,
        width_shift_range=shift_range,
        height_shift_range=shift_range,
        horizontal_flip=horizontal_flip,
        vertical_flip=vertical_flip,
        zoom_range=zoom_range,
        fill_mode=fill_mode)
    
    train_start = datetime.datetime.now()
    history = net.train(datagen, X_train, y_train, (X_val, y_val), epochs=epochs, batch_size=batch_size,)
    train_finish = datetime.datetime.now()
    train_duration = (train_finish - train_start).seconds
    
    model_name = curr_date() # name of the directory for model
    root_directory = '/home/stanislau/repository/machine-learning/brodatz/results/'
    directory_name = root_directory + curr_date()
    if not os.path.exists(directory_name):
        os.makedirs(directory_name) # create directory
        
    save_history(directory_name + '/loss.png', directory_name + '/accuracy.png', history) # save plots of loss and accuracy
        
    model_json = net.model.to_json()
    with open(directory_name + "/model.json", "w") as json_file:
        json_file.write(model_json) # save model to file
        
    utils.plot_model(net.model, to_file=directory_name + "/model.png", show_shapes=True) # save model png overview to file
    
    count_params = net.model.count_params() # number of model parameters
    optimizer_json = json.dumps(optimizers.serialize(optimizer))
    with open(directory_name + "/optimizer.json", "w") as json_file:
        json_file.write(optimizer_json) # save optimizer to file

    models_battles_filename = root_directory + 'models_battles.csv'
    header = ['Model name', 'X_train', 'X_test', 'X_test1', 'X_test2', 'X_test3', 'X_test4',
              'Epochs', 'Number of parameters', 'Batches', 'Learning rate', 'Train duration',
              'Rotation range', 'Shear range', 'Shift range', 'Hor flip', 'Ver flip', 'Zoom range', 'Fill mode',
              'Number of classes',
              'Regularization Strength']
    accuracies = [net.accuracy(X_test, y_test) for X_test, y_test, _ in [(X_train, y_train, num_classes)] + test_list]
    data = [model_name]
    data.extend(accuracies)
    number_of_params = net.model.count_params()
    data.extend([epochs, number_of_params, batch_size, learning_rate, train_duration])
    data.extend([rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode])
    data.append(num_classes)
    data.append(regularization_strength)
    if not os.path.isfile(models_battles_filename):
        df = pd.DataFrame([data], columns=header)
        df.to_csv(models_battles_filename)
    else:
        with open(models_battles_filename, 'a') as f:
            df = pd.DataFrame([data])
            df.to_csv(f, header=False)

rotation_ranges = [0, 45, 90, 135, 180]
shear_ranges = [0, 0.2, 0.25, 1/3, 0.5, 0.75, 1]
# shift_ranges = [0, 0.15, 0.2, 0.3, 0.4, 0.45]
shift_ranges = [0, 0.2, 0.3, 0.4, 0.5]
horizontal_flips = [True, False]
vertical_flips = [True, False]
zoom_ranges = [0, 0.2, 0.35, 0.5, 0.7, [0.55, 0.65], [0.6, 0.7]]
fill_modes = ['reflect', 'nearest', 'wrap']
learning_rates = [0.001, 0.002, 0.005, 0.01]
regularization_strengths = [0.001, 0.01, 0.05, 0.1]

rotation_range = rotation_ranges[4]
shear_range = shear_ranges[0]
shift_range = shift_ranges[3]
horizontal_flip = horizontal_flips[0]
vertical_flip = vertical_flips[0]
zoom_range = zoom_ranges[0]
fill_mode = fill_modes[0]
batch_size = 64
epochs = 350
learning_rate = learning_rates[1]
regularization_strength = regularization_strengths[1]


try_args(rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs, learning_rate, regularization_strength)

# for shear_range in shear_ranges:
#     try_args(rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs)

# %%
fill_modes[::2]

# %%
zoom_ranges = [0, 0.2, 0.35, 0.5, 0.7, [0.55, 0.65], [0.6, 0.7], [1.4, 1.5], [1.45, 1.55]]

# %%
zoom_ranges[5:]

# %%
shift_ranges[2:5]

# %%
import json
import pandas as pd
import datetime

def try_args(rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode,
             batch_size, epochs, learning_rate, regularization_strength):
    input_shape = X_train[0].shape
    
    learning_rate = learning_rate
    regularizer = regularizers.l2(regularization_strength)
    optimizer = optimizers.SGD(lr=learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
#     optimizer = optimizers.Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

   
    net = KerasNeuralNetwork(input_shape, num_classes, regularizer=regularizer, optimizer=optimizer)
    net.compile_model_9()
    
    datagen = ImageDataGenerator(
        rotation_range=rotation_range,
        shear_range=np.pi * shear_range,
        width_shift_range=shift_range,
        height_shift_range=shift_range,
        horizontal_flip=horizontal_flip,
        vertical_flip=vertical_flip,
        zoom_range=zoom_range,
        fill_mode=fill_mode)
    
    train_start = datetime.datetime.now()
    history = net.train(datagen, X_train, y_train, (X_val, y_val), epochs=epochs, batch_size=batch_size,)
    train_finish = datetime.datetime.now()
    train_duration = (train_finish - train_start).seconds
    
    model_name = curr_date() # name of the directory for model
    root_directory = '/home/stanislau/repository/machine-learning/brodatz/results/'
    directory_name = root_directory + curr_date()
    if not os.path.exists(directory_name):
        os.makedirs(directory_name) # create directory
        
    save_history(directory_name + '/loss.png', directory_name + '/accuracy.png', history) # save plots of loss and accuracy
        
    model_json = net.model.to_json()
    with open(directory_name + "/model.json", "w") as json_file:
        json_file.write(model_json) # save model to file
        
    utils.plot_model(net.model, to_file=directory_name + "/model.png", show_shapes=True) # save model png overview to file
    
    count_params = net.model.count_params() # number of model parameters
    optimizer_json = json.dumps(optimizers.serialize(optimizer))
    with open(directory_name + "/optimizer.json", "w") as json_file:
        json_file.write(optimizer_json) # save optimizer to file

    models_battles_filename = root_directory + 'models_battles.csv'
    header = ['Model name', 'X_train', 'X_test', 'X_test1', 'X_test2', 'X_test3', 'X_test4',
              'Epochs', 'Number of parameters', 'Batches', 'Learning rate', 'Train duration',
              'Rotation range', 'Shear range', 'Shift range', 'Hor flip', 'Ver flip', 'Zoom range', 'Fill mode',
              'Number of classes',
              'Regularization Strength']
    accuracies = [net.accuracy(X_test, y_test) for X_test, y_test, _ in [(X_train, y_train, num_classes)] + test_list]
    data = [model_name]
    data.extend(accuracies)
    number_of_params = net.model.count_params()
    data.extend([epochs, number_of_params, batch_size, learning_rate, train_duration])
    data.extend([rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode])
    data.append(num_classes)
    data.append(regularization_strength)
    if not os.path.isfile(models_battles_filename):
        df = pd.DataFrame([data], columns=header)
        df.to_csv(models_battles_filename)
    else:
        with open(models_battles_filename, 'a') as f:
            df = pd.DataFrame([data])
            df.to_csv(f, header=False)

rotation_ranges = [0, 45, 90, 135, 180]
shear_ranges = [0, 0.2, 0.25, 1/3, 0.5, 0.75, 1]
# shift_ranges = [0, 0.15, 0.2, 0.3, 0.4, 0.45]
shift_ranges = [0, 0.2, 0.3, 0.4, 0.5]
horizontal_flips = [True, False]
vertical_flips = [True, False]
zoom_ranges = [0, 0.2, 0.35, 0.5, 0.7, [0.55, 0.65], [0.6, 0.7]]
fill_modes = ['reflect', 'nearest', 'wrap']
learning_rates = [0.001, 0.002, 0.005, 0.01]
regularization_strengths = [0.001, 0.01, 0.05, 0.1]

rotation_range = rotation_ranges[4]
shear_range = shear_ranges[0]
shift_range = shift_ranges[3]
horizontal_flip = horizontal_flips[0]
vertical_flip = vertical_flips[0]
zoom_range = zoom_ranges[0]
fill_mode = fill_modes[0]
batch_size = 64
epochs = 350
learning_rate = learning_rates[1]
regularization_strength = regularization_strengths[1]


try_args(rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs, learning_rate, regularization_strength)

# for shear_range in shear_ranges:
#     try_args(rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs)

# %%
input_shape = X_train[0].shape

learning_rate = 0.002
regularization_strength = 0.01
regularizer = regularizers.l2(regularization_strength)
optimizer = optimizers.SGD(lr=learning_rate, decay=1e-6, momentum=0.9, nesterov=True)

net = KerasNeuralNetwork(input_shape, num_classes, regularizer=regularizer, optimizer=optimizer)
net.compile_model_3()

# %%
b = brodatz_generator(X_train, y_train, batch_size=64)

# %%
shift_generator = ImageDataGenerator(
    width_shift_range=0.5,
    height_shift_range=0.5,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='reflect')

zoom_in_generator = ImageDataGenerator(
    width_shift_range=0.4,
    height_shift_range=0.4,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=[0.55, 0.65],
    fill_mode='reflect')

zoom_out_generator = ImageDataGenerator(
    width_shift_range=0.3,
    height_shift_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=[1.45, 1.55],
    fill_mode='reflect')

rotation_generator = ImageDataGenerator(
    rotation_range=180,
    width_shift_range=0.4,
    height_shift_range=0.4,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='reflect')

# %%
X_val.shape

# %%
X_val = np.zeros((2220, 200, 200, 1))
y_val = np.zeros((2220, 111))

batch_size = 20

g = brodatz_generator(X_train, y_train, batch_size=batch_size)

i = 0
for batch in g:
    X_val[i*batch_size:(i+1)*batch_size] = batch[0]
    y_val[i*batch_size:(i+1)*batch_size] = batch[1]
    
    i += 1
    if i == 111:
        break

# %%
batch_size = 64

history = net.train_generator(brodatz_generator(X_train, y_train, batch_size=batch_size), validation_data=(X_val, y_val), steps_per_epoch=len(X_train)/batch_size*4, epochs=200)
# Out:
# Epoch 1/200
# 35/34 [==============================] - 7s 187ms/step - loss: 8.1943 - acc: 0.0099 - val_loss: 8.1380 - val_acc: 0.0090
# Epoch 2/200
# 35/34 [==============================] - 5s 140ms/step - loss: 8.0885 - acc: 0.0082 - val_loss: 8.0285 - val_acc: 0.0090
# Epoch 3/200
# 35/34 [==============================] - 5s 136ms/step - loss: 7.9790 - acc: 0.0086 - val_loss: 7.9180 - val_acc: 0.0104
# Epoch 4/200
# 35/34 [==============================] - 5s 140ms/step - loss: 7.8682 - acc: 0.0103 - val_loss: 7.8035 - val_acc: 0.0099
# Epoch 5/200
# 35/34 [==============================] - 5s 141ms/step - loss: 7.7500 - acc: 0.0104 - val_loss: 7.6843 - val_acc: 0.0113
# Epoch 6/200
# 35/34 [==============================] - 5s 140ms/step - loss: 7.6355 - acc: 0.0136 - val_loss: 7.5605 - val_acc: 0.0149
# Epoch 7/200
# 35/34 [==============================] - 5s 142ms/step - loss: 7.5071 - acc: 0.0209 - val_loss: 7.4256 - val_acc: 0.0239
# Epoch 8/200
# 35/34 [==============================] - 5s 141ms/step - loss: 7.3705 - acc: 0.0219 - val_loss: 7.2672 - val_acc: 0.0252
# Epoch 9/200
# 35/34 [==============================] - 5s 142ms/step - loss: 7.2058 - acc: 0.0220 - val_loss: 7.0816 - val_acc: 0.0365
# Epoch 10/200
# 35/34 [==============================] - 5s 140ms/step - loss: 7.0383 - acc: 0.0228 - val_loss: 6.8877 - val_acc: 0.0387
# Epoch 11/200
# 35/34 [==============================] - 5s 142ms/step - loss: 6.8689 - acc: 0.0323 - val_loss: 6.7475 - val_acc: 0.0351
# Epoch 12/200
# 35/34 [==============================] - 5s 143ms/step - loss: 6.7427 - acc: 0.0271 - val_loss: 6.5921 - val_acc: 0.0437
# Epoch 13/200
# 35/34 [==============================] - 5s 141ms/step - loss: 6.6010 - acc: 0.0348 - val_loss: 6.4730 - val_acc: 0.0541
# Epoch 14/200
# 35/34 [==============================] - 5s 142ms/step - loss: 6.5084 - acc: 0.0370 - val_loss: 6.3448 - val_acc: 0.0766
# Epoch 15/200
# 35/34 [==============================] - 5s 145ms/step - loss: 6.3831 - acc: 0.0557 - val_loss: 6.2688 - val_acc: 0.0707
# Epoch 16/200
# 35/34 [==============================] - 5s 144ms/step - loss: 6.2714 - acc: 0.0628 - val_loss: 6.1208 - val_acc: 0.0838
# Epoch 17/200
# 35/34 [==============================] - 5s 141ms/step - loss: 6.1448 - acc: 0.0683 - val_loss: 6.0398 - val_acc: 0.0982
# Epoch 18/200
# 35/34 [==============================] - 5s 140ms/step - loss: 6.0134 - acc: 0.0890 - val_loss: 5.8640 - val_acc: 0.1221
# Epoch 19/200
# 35/34 [==============================] - 5s 142ms/step - loss: 5.8850 - acc: 0.1014 - val_loss: 5.7564 - val_acc: 0.1198
# Epoch 20/200
# 35/34 [==============================] - 5s 141ms/step - loss: 5.7610 - acc: 0.1108 - val_loss: 5.5878 - val_acc: 0.1581
# Epoch 21/200
# 35/34 [==============================] - 5s 139ms/step - loss: 5.6313 - acc: 0.1329 - val_loss: 5.5565 - val_acc: 0.1613
# Epoch 22/200
# 35/34 [==============================] - 5s 142ms/step - loss: 5.4740 - acc: 0.1465 - val_loss: 5.3384 - val_acc: 0.1919
# Epoch 23/200
# 35/34 [==============================] - 5s 144ms/step - loss: 5.4113 - acc: 0.1552 - val_loss: 5.2659 - val_acc: 0.1950
# Epoch 24/200
# 35/34 [==============================] - 5s 154ms/step - loss: 5.2635 - acc: 0.1819 - val_loss: 5.0786 - val_acc: 0.2297
# Epoch 25/200
# 35/34 [==============================] - 5s 152ms/step - loss: 5.1612 - acc: 0.1925 - val_loss: 5.0132 - val_acc: 0.2572
# Epoch 26/200
# 35/34 [==============================] - 5s 141ms/step - loss: 5.0108 - acc: 0.2120 - val_loss: 4.9220 - val_acc: 0.2239
# Epoch 27/200
# 35/34 [==============================] - 5s 143ms/step - loss: 4.9864 - acc: 0.2261 - val_loss: 4.7715 - val_acc: 0.2577
# Epoch 28/200
# 35/34 [==============================] - 5s 141ms/step - loss: 4.8099 - acc: 0.2438 - val_loss: 4.6812 - val_acc: 0.2667
# Epoch 29/200
# 35/34 [==============================] - 5s 141ms/step - loss: 4.6984 - acc: 0.2540 - val_loss: 4.6125 - val_acc: 0.2694
# Epoch 30/200
# 35/34 [==============================] - 5s 141ms/step - loss: 4.7156 - acc: 0.2622 - val_loss: 4.4896 - val_acc: 0.2941
# Epoch 31/200
# 35/34 [==============================] - 5s 141ms/step - loss: 4.5418 - acc: 0.2719 - val_loss: 4.4716 - val_acc: 0.3342
# Epoch 32/200
# 35/34 [==============================] - 5s 142ms/step - loss: 4.4717 - acc: 0.2932 - val_loss: 4.4027 - val_acc: 0.2860
# Epoch 33/200
# 35/34 [==============================] - 5s 141ms/step - loss: 4.4065 - acc: 0.2994 - val_loss: 4.2985 - val_acc: 0.3059
# Epoch 34/200
# 35/34 [==============================] - 5s 142ms/step - loss: 4.2643 - acc: 0.3330 - val_loss: 4.3961 - val_acc: 0.2829
# Epoch 35/200
# 35/34 [==============================] - 5s 146ms/step - loss: 4.2456 - acc: 0.3291 - val_loss: 4.0462 - val_acc: 0.3626
# Epoch 36/200
# 35/34 [==============================] - 5s 147ms/step - loss: 4.1343 - acc: 0.3327 - val_loss: 3.9543 - val_acc: 0.4090
# Epoch 37/200
# 35/34 [==============================] - 5s 140ms/step - loss: 4.0535 - acc: 0.3641 - val_loss: 3.8820 - val_acc: 0.4162
# Epoch 38/200
# 35/34 [==============================] - 5s 140ms/step - loss: 3.9656 - acc: 0.3655 - val_loss: 3.9331 - val_acc: 0.3685
# Epoch 39/200
# 35/34 [==============================] - 5s 140ms/step - loss: 3.9040 - acc: 0.3859 - val_loss: 3.7671 - val_acc: 0.4095
# Epoch 40/200
# 35/34 [==============================] - 5s 143ms/step - loss: 3.8203 - acc: 0.3954 - val_loss: 3.7995 - val_acc: 0.4095
# Epoch 41/200
# 35/34 [==============================] - 5s 142ms/step - loss: 3.7761 - acc: 0.4014 - val_loss: 3.7584 - val_acc: 0.4270
# Epoch 42/200
# 35/34 [==============================] - 5s 141ms/step - loss: 3.7578 - acc: 0.4246 - val_loss: 3.6694 - val_acc: 0.4216
# Epoch 43/200
# 35/34 [==============================] - 5s 138ms/step - loss: 3.6405 - acc: 0.4341 - val_loss: 3.5322 - val_acc: 0.4495
# Epoch 44/200
# 35/34 [==============================] - 5s 145ms/step - loss: 3.6019 - acc: 0.4298 - val_loss: 3.4033 - val_acc: 0.4991
# Epoch 45/200
# 35/34 [==============================] - 5s 146ms/step - loss: 3.5415 - acc: 0.4454 - val_loss: 3.4687 - val_acc: 0.4532
# Epoch 46/200
# 35/34 [==============================] - 5s 144ms/step - loss: 3.4449 - acc: 0.4597 - val_loss: 3.2945 - val_acc: 0.5005
# Epoch 47/200
# 35/34 [==============================] - 5s 143ms/step - loss: 3.3993 - acc: 0.4728 - val_loss: 3.4811 - val_acc: 0.4315
# Epoch 48/200
# 35/34 [==============================] - 5s 141ms/step - loss: 3.3213 - acc: 0.4738 - val_loss: 3.2056 - val_acc: 0.5329
# Epoch 49/200
# 35/34 [==============================] - 5s 144ms/step - loss: 3.2819 - acc: 0.4883 - val_loss: 3.2225 - val_acc: 0.5126
# Epoch 50/200
# 35/34 [==============================] - 5s 144ms/step - loss: 3.2309 - acc: 0.4953 - val_loss: 3.1547 - val_acc: 0.5059
# Epoch 51/200
# 35/34 [==============================] - 5s 142ms/step - loss: 3.1747 - acc: 0.5231 - val_loss: 2.9826 - val_acc: 0.5761
# Epoch 52/200
# 35/34 [==============================] - 5s 140ms/step - loss: 3.1228 - acc: 0.5273 - val_loss: 3.0291 - val_acc: 0.5581
# Epoch 53/200
# 35/34 [==============================] - 5s 141ms/step - loss: 3.1209 - acc: 0.5157 - val_loss: 3.0040 - val_acc: 0.5635
# Epoch 54/200
# 35/34 [==============================] - 5s 141ms/step - loss: 3.0598 - acc: 0.5411 - val_loss: 2.9935 - val_acc: 0.5532
# Epoch 55/200
# 35/34 [==============================] - 5s 144ms/step - loss: 3.0452 - acc: 0.5315 - val_loss: 2.8918 - val_acc: 0.5635
# Epoch 56/200
# 35/34 [==============================] - 5s 144ms/step - loss: 2.9673 - acc: 0.5504 - val_loss: 2.8081 - val_acc: 0.6099
# Epoch 57/200
# 35/34 [==============================] - 5s 142ms/step - loss: 2.9561 - acc: 0.5602 - val_loss: 2.8011 - val_acc: 0.5847
# Epoch 58/200
# 35/34 [==============================] - 5s 143ms/step - loss: 2.9417 - acc: 0.5638 - val_loss: 2.8465 - val_acc: 0.5640
# Epoch 59/200
# 35/34 [==============================] - 5s 145ms/step - loss: 2.8488 - acc: 0.5677 - val_loss: 2.6802 - val_acc: 0.6203
# Epoch 60/200
# 35/34 [==============================] - 5s 145ms/step - loss: 2.8151 - acc: 0.5772 - val_loss: 2.6125 - val_acc: 0.6342
# Epoch 61/200
# 35/34 [==============================] - 5s 140ms/step - loss: 2.7432 - acc: 0.6023 - val_loss: 2.7139 - val_acc: 0.5923
# Epoch 62/200
# 35/34 [==============================] - 5s 143ms/step - loss: 2.7529 - acc: 0.5899 - val_loss: 2.6966 - val_acc: 0.6036
# Epoch 63/200
# 35/34 [==============================] - 5s 141ms/step - loss: 2.7061 - acc: 0.5938 - val_loss: 2.5841 - val_acc: 0.6365
# Epoch 64/200
# 35/34 [==============================] - 5s 141ms/step - loss: 2.6867 - acc: 0.6051 - val_loss: 2.5427 - val_acc: 0.6491
# Epoch 65/200
# 35/34 [==============================] - 5s 141ms/step - loss: 2.6958 - acc: 0.6041 - val_loss: 2.5710 - val_acc: 0.6311
# Epoch 66/200
# 35/34 [==============================] - 5s 143ms/step - loss: 2.6201 - acc: 0.6182 - val_loss: 2.5446 - val_acc: 0.6459
# Epoch 67/200
# 35/34 [==============================] - 5s 143ms/step - loss: 2.5593 - acc: 0.6223 - val_loss: 2.6397 - val_acc: 0.5946
# Epoch 68/200
# 35/34 [==============================] - 5s 139ms/step - loss: 2.5424 - acc: 0.6293 - val_loss: 2.4849 - val_acc: 0.6401
# Epoch 69/200
# 35/34 [==============================] - 5s 144ms/step - loss: 2.5244 - acc: 0.6351 - val_loss: 2.4738 - val_acc: 0.6500
# Epoch 70/200
# 35/34 [==============================] - 5s 141ms/step - loss: 2.5838 - acc: 0.6263 - val_loss: 2.4128 - val_acc: 0.6739
# Epoch 71/200
# 35/34 [==============================] - 5s 140ms/step - loss: 2.5326 - acc: 0.6405 - val_loss: 2.7215 - val_acc: 0.5712
# Epoch 72/200
# 35/34 [==============================] - 5s 143ms/step - loss: 2.4312 - acc: 0.6646 - val_loss: 2.5253 - val_acc: 0.6050
# Epoch 73/200
# 35/34 [==============================] - 5s 140ms/step - loss: 2.4662 - acc: 0.6446 - val_loss: 2.3620 - val_acc: 0.6698
# Epoch 74/200
# 35/34 [==============================] - 5s 140ms/step - loss: 2.4206 - acc: 0.6424 - val_loss: 2.3204 - val_acc: 0.6734
# Epoch 75/200
# 35/34 [==============================] - 5s 143ms/step - loss: 2.4320 - acc: 0.6526 - val_loss: 2.6479 - val_acc: 0.5797
# Epoch 76/200
# 35/34 [==============================] - 5s 148ms/step - loss: 2.4234 - acc: 0.6420 - val_loss: 2.2925 - val_acc: 0.6779
# Epoch 77/200
# 35/34 [==============================] - 5s 142ms/step - loss: 2.3718 - acc: 0.6572 - val_loss: 2.2349 - val_acc: 0.7158
# Epoch 78/200
# 35/34 [==============================] - 5s 143ms/step - loss: 2.3268 - acc: 0.6726 - val_loss: 2.2140 - val_acc: 0.7063
# Epoch 79/200
# 35/34 [==============================] - 5s 141ms/step - loss: 2.2784 - acc: 0.6898 - val_loss: 2.1734 - val_acc: 0.7185
# Epoch 80/200
# 35/34 [==============================] - 5s 143ms/step - loss: 2.2549 - acc: 0.6905 - val_loss: 2.2115 - val_acc: 0.6946
# Epoch 81/200
# 35/34 [==============================] - 5s 141ms/step - loss: 2.2475 - acc: 0.6858 - val_loss: 2.1349 - val_acc: 0.7297
# Epoch 82/200
# 35/34 [==============================] - 5s 140ms/step - loss: 2.2812 - acc: 0.6752 - val_loss: 2.2141 - val_acc: 0.7045
# Epoch 83/200
# 35/34 [==============================] - 5s 140ms/step - loss: 2.2584 - acc: 0.6963 - val_loss: 2.1702 - val_acc: 0.7180
# Epoch 84/200
# 35/34 [==============================] - 5s 142ms/step - loss: 2.2116 - acc: 0.7068 - val_loss: 2.2044 - val_acc: 0.6874
# Epoch 85/200
# 35/34 [==============================] - 5s 141ms/step - loss: 2.1641 - acc: 0.7216 - val_loss: 2.1783 - val_acc: 0.7072
# Epoch 86/200
# 35/34 [==============================] - 5s 140ms/step - loss: 2.2376 - acc: 0.6864 - val_loss: 2.1225 - val_acc: 0.7306
# Epoch 87/200
# 35/34 [==============================] - 5s 143ms/step - loss: 2.1509 - acc: 0.7092 - val_loss: 2.0681 - val_acc: 0.7419
# Epoch 88/200
# 35/34 [==============================] - 5s 141ms/step - loss: 2.1644 - acc: 0.7080 - val_loss: 2.1991 - val_acc: 0.6883
# Epoch 89/200
# 35/34 [==============================] - 5s 143ms/step - loss: 2.1503 - acc: 0.7091 - val_loss: 2.0346 - val_acc: 0.7459
# Epoch 90/200
# 35/34 [==============================] - 5s 144ms/step - loss: 2.1373 - acc: 0.7227 - val_loss: 2.0974 - val_acc: 0.7203
# Epoch 91/200
# 35/34 [==============================] - 5s 146ms/step - loss: 2.0726 - acc: 0.7201 - val_loss: 2.0723 - val_acc: 0.7239
# Epoch 92/200
# 35/34 [==============================] - 5s 141ms/step - loss: 2.1340 - acc: 0.7182 - val_loss: 1.9828 - val_acc: 0.7536
# Epoch 93/200
# 35/34 [==============================] - 5s 140ms/step - loss: 2.1139 - acc: 0.7293 - val_loss: 2.1469 - val_acc: 0.7077
# Epoch 94/200
# 35/34 [==============================] - 5s 140ms/step - loss: 2.1283 - acc: 0.7121 - val_loss: 2.0185 - val_acc: 0.7523
# Epoch 95/200
# 35/34 [==============================] - 5s 140ms/step - loss: 2.0351 - acc: 0.7369 - val_loss: 1.9742 - val_acc: 0.7545
# Epoch 96/200
# 35/34 [==============================] - 5s 142ms/step - loss: 2.0301 - acc: 0.7394 - val_loss: 1.9490 - val_acc: 0.7626
# Epoch 97/200
# 35/34 [==============================] - 5s 140ms/step - loss: 2.0938 - acc: 0.7242 - val_loss: 1.9310 - val_acc: 0.7824
# Epoch 98/200
# 35/34 [==============================] - 5s 142ms/step - loss: 2.0315 - acc: 0.7440 - val_loss: 1.9809 - val_acc: 0.7459
# Epoch 99/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.9839 - acc: 0.7540 - val_loss: 1.9133 - val_acc: 0.7671
# Epoch 100/200
# 35/34 [==============================] - 5s 141ms/step - loss: 2.0206 - acc: 0.7309 - val_loss: 1.9672 - val_acc: 0.7459
# Epoch 101/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.9937 - acc: 0.7478 - val_loss: 1.9362 - val_acc: 0.7779
# Epoch 102/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.9931 - acc: 0.7452 - val_loss: 1.9745 - val_acc: 0.7437
# Epoch 103/200
# 35/34 [==============================] - 5s 148ms/step - loss: 1.9623 - acc: 0.7578 - val_loss: 1.9481 - val_acc: 0.7631
# Epoch 104/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.9836 - acc: 0.7426 - val_loss: 1.8565 - val_acc: 0.7923
# Epoch 105/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.9502 - acc: 0.7499 - val_loss: 1.8558 - val_acc: 0.7860
# Epoch 106/200
# 35/34 [==============================] - 5s 145ms/step - loss: 2.0112 - acc: 0.7330 - val_loss: 1.8859 - val_acc: 0.7653
# Epoch 107/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.9471 - acc: 0.7468 - val_loss: 1.8641 - val_acc: 0.7721
# Epoch 108/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.9088 - acc: 0.7682 - val_loss: 1.8909 - val_acc: 0.7671
# Epoch 109/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.9439 - acc: 0.7464 - val_loss: 1.9089 - val_acc: 0.7653
# Epoch 110/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.9768 - acc: 0.7445 - val_loss: 1.9128 - val_acc: 0.7523
# Epoch 111/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.9019 - acc: 0.7635 - val_loss: 1.8544 - val_acc: 0.7743
# Epoch 112/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.8932 - acc: 0.7582 - val_loss: 1.8025 - val_acc: 0.7856
# Epoch 113/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.8649 - acc: 0.7663 - val_loss: 1.8248 - val_acc: 0.7730
# Epoch 114/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.8678 - acc: 0.7625 - val_loss: 1.7800 - val_acc: 0.7932
# Epoch 115/200
# 35/34 [==============================] - 5s 139ms/step - loss: 1.8848 - acc: 0.7666 - val_loss: 1.8914 - val_acc: 0.7518
# Epoch 116/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.8483 - acc: 0.7837 - val_loss: 1.7709 - val_acc: 0.7847
# Epoch 117/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.8515 - acc: 0.7660 - val_loss: 1.8351 - val_acc: 0.7833
# Epoch 118/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.8681 - acc: 0.7646 - val_loss: 1.7589 - val_acc: 0.8045
# Epoch 119/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.8730 - acc: 0.7686 - val_loss: 1.7951 - val_acc: 0.7815
# Epoch 120/200
# 35/34 [==============================] - 5s 145ms/step - loss: 1.8563 - acc: 0.7695 - val_loss: 1.8830 - val_acc: 0.7941
# Epoch 121/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.8618 - acc: 0.7779 - val_loss: 1.8163 - val_acc: 0.7734
# Epoch 122/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.8344 - acc: 0.7773 - val_loss: 1.7634 - val_acc: 0.7869
# Epoch 123/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.8558 - acc: 0.7729 - val_loss: 1.7156 - val_acc: 0.8275
# Epoch 124/200
# 35/34 [==============================] - 5s 143ms/step - loss: 1.7976 - acc: 0.7892 - val_loss: 1.7510 - val_acc: 0.8122
# Epoch 125/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.8243 - acc: 0.7866 - val_loss: 1.7079 - val_acc: 0.8140
# Epoch 126/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.7802 - acc: 0.7803 - val_loss: 1.8264 - val_acc: 0.7716
# Epoch 127/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.7891 - acc: 0.7799 - val_loss: 1.7650 - val_acc: 0.7865
# Epoch 128/200
# 35/34 [==============================] - 5s 139ms/step - loss: 1.7813 - acc: 0.7894 - val_loss: 1.7431 - val_acc: 0.8054
# Epoch 129/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.8038 - acc: 0.7772 - val_loss: 1.6980 - val_acc: 0.8153
# Epoch 130/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.7552 - acc: 0.7973 - val_loss: 1.8105 - val_acc: 0.7649
# Epoch 131/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.7939 - acc: 0.7787 - val_loss: 1.8351 - val_acc: 0.7613
# Epoch 132/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.7672 - acc: 0.7911 - val_loss: 1.6773 - val_acc: 0.8293
# Epoch 133/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.7525 - acc: 0.8001 - val_loss: 1.6695 - val_acc: 0.8216
# Epoch 134/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.7302 - acc: 0.7971 - val_loss: 1.6787 - val_acc: 0.8230
# Epoch 135/200
# 35/34 [==============================] - 5s 143ms/step - loss: 1.7241 - acc: 0.7960 - val_loss: 1.6296 - val_acc: 0.8320
# Epoch 136/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.7338 - acc: 0.7979 - val_loss: 1.6429 - val_acc: 0.8261
# Epoch 137/200
# 35/34 [==============================] - 5s 143ms/step - loss: 1.6917 - acc: 0.8145 - val_loss: 1.7865 - val_acc: 0.7757
# Epoch 138/200
# 35/34 [==============================] - 5s 139ms/step - loss: 1.7066 - acc: 0.8067 - val_loss: 1.6780 - val_acc: 0.8149
# Epoch 139/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.7469 - acc: 0.7854 - val_loss: 1.6691 - val_acc: 0.8261
# Epoch 140/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.7166 - acc: 0.8077 - val_loss: 1.6667 - val_acc: 0.8063
# Epoch 141/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.6835 - acc: 0.8119 - val_loss: 1.6716 - val_acc: 0.8216
# Epoch 142/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.7133 - acc: 0.7977 - val_loss: 1.7492 - val_acc: 0.7968
# Epoch 143/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.7128 - acc: 0.8033 - val_loss: 1.6137 - val_acc: 0.8351
# Epoch 144/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.7059 - acc: 0.8043 - val_loss: 1.6095 - val_acc: 0.8360
# Epoch 145/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.6952 - acc: 0.8109 - val_loss: 1.6178 - val_acc: 0.8329
# Epoch 146/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.6913 - acc: 0.8107 - val_loss: 1.6851 - val_acc: 0.8126
# Epoch 147/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.6959 - acc: 0.7989 - val_loss: 1.6559 - val_acc: 0.8342
# Epoch 148/200
# 35/34 [==============================] - 5s 143ms/step - loss: 1.6992 - acc: 0.8100 - val_loss: 1.6041 - val_acc: 0.8419
# Epoch 149/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.7203 - acc: 0.8072 - val_loss: 1.6013 - val_acc: 0.8446
# Epoch 150/200
# 35/34 [==============================] - 5s 139ms/step - loss: 1.6681 - acc: 0.8028 - val_loss: 1.5954 - val_acc: 0.8410
# Epoch 151/200
# 35/34 [==============================] - 5s 143ms/step - loss: 1.6394 - acc: 0.8286 - val_loss: 1.5735 - val_acc: 0.8419
# Epoch 152/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.6758 - acc: 0.8136 - val_loss: 1.5645 - val_acc: 0.8374
# Epoch 153/200
# 35/34 [==============================] - 5s 144ms/step - loss: 1.6539 - acc: 0.8217 - val_loss: 1.5920 - val_acc: 0.8486
# Epoch 154/200
# 35/34 [==============================] - 5s 143ms/step - loss: 1.6835 - acc: 0.8139 - val_loss: 1.6219 - val_acc: 0.8293
# Epoch 155/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.6479 - acc: 0.8287 - val_loss: 1.5860 - val_acc: 0.8356
# Epoch 156/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.6442 - acc: 0.8241 - val_loss: 1.6204 - val_acc: 0.8189
# Epoch 157/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.6567 - acc: 0.8196 - val_loss: 1.5564 - val_acc: 0.8495
# Epoch 158/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.6758 - acc: 0.8060 - val_loss: 1.6045 - val_acc: 0.8329
# Epoch 159/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.6528 - acc: 0.8205 - val_loss: 1.5276 - val_acc: 0.8554
# Epoch 160/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.6398 - acc: 0.8158 - val_loss: 1.5649 - val_acc: 0.8360
# Epoch 161/200
# 35/34 [==============================] - 5s 144ms/step - loss: 1.6331 - acc: 0.8282 - val_loss: 1.5711 - val_acc: 0.8423
# Epoch 162/200
# 35/34 [==============================] - 5s 139ms/step - loss: 1.6624 - acc: 0.8103 - val_loss: 1.5649 - val_acc: 0.8464
# Epoch 163/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.6620 - acc: 0.8134 - val_loss: 1.5999 - val_acc: 0.8365
# Epoch 164/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.6317 - acc: 0.8235 - val_loss: 1.6436 - val_acc: 0.8203
# Epoch 165/200
# 35/34 [==============================] - 5s 139ms/step - loss: 1.6479 - acc: 0.8163 - val_loss: 1.5484 - val_acc: 0.8450
# Epoch 166/200
# 35/34 [==============================] - 5s 144ms/step - loss: 1.6248 - acc: 0.8383 - val_loss: 1.6016 - val_acc: 0.8360
# Epoch 167/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.5871 - acc: 0.8401 - val_loss: 1.5388 - val_acc: 0.8527
# Epoch 168/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.6376 - acc: 0.8178 - val_loss: 1.7083 - val_acc: 0.7860
# Epoch 169/200
# 35/34 [==============================] - 5s 143ms/step - loss: 1.6336 - acc: 0.8265 - val_loss: 1.5949 - val_acc: 0.8311
# Epoch 170/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.6150 - acc: 0.8395 - val_loss: 1.5400 - val_acc: 0.8495
# Epoch 171/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.6021 - acc: 0.8282 - val_loss: 1.6180 - val_acc: 0.8257
# Epoch 172/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.6139 - acc: 0.8257 - val_loss: 1.6168 - val_acc: 0.8342
# Epoch 173/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.6019 - acc: 0.8391 - val_loss: 1.5406 - val_acc: 0.8455
# Epoch 174/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.5936 - acc: 0.8300 - val_loss: 1.6822 - val_acc: 0.7973
# Epoch 175/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.6062 - acc: 0.8292 - val_loss: 1.4963 - val_acc: 0.8707
# Epoch 176/200
# 35/34 [==============================] - 5s 143ms/step - loss: 1.6017 - acc: 0.8285 - val_loss: 1.5395 - val_acc: 0.8464
# Epoch 177/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.6284 - acc: 0.8201 - val_loss: 1.5859 - val_acc: 0.8324
# Epoch 178/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.5595 - acc: 0.8471 - val_loss: 1.5279 - val_acc: 0.8527
# Epoch 179/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.5964 - acc: 0.8377 - val_loss: 1.5624 - val_acc: 0.8419
# Epoch 180/200
# 35/34 [==============================] - 5s 143ms/step - loss: 1.5769 - acc: 0.8421 - val_loss: 1.5980 - val_acc: 0.8284
# Epoch 181/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.6089 - acc: 0.8254 - val_loss: 1.5276 - val_acc: 0.8527
# Epoch 182/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.5855 - acc: 0.8417 - val_loss: 1.6110 - val_acc: 0.8329
# Epoch 183/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.5594 - acc: 0.8439 - val_loss: 1.5031 - val_acc: 0.8595
# Epoch 184/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.6037 - acc: 0.8235 - val_loss: 1.5499 - val_acc: 0.8559
# Epoch 185/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.5447 - acc: 0.8527 - val_loss: 1.5125 - val_acc: 0.8653
# Epoch 186/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.6036 - acc: 0.8318 - val_loss: 1.5530 - val_acc: 0.8500
# Epoch 187/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.6294 - acc: 0.8156 - val_loss: 1.5226 - val_acc: 0.8586
# Epoch 188/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.6054 - acc: 0.8211 - val_loss: 1.5541 - val_acc: 0.8495
# Epoch 189/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.5798 - acc: 0.8330 - val_loss: 1.5451 - val_acc: 0.8482
# Epoch 190/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.5894 - acc: 0.8377 - val_loss: 1.5090 - val_acc: 0.8671
# Epoch 191/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.5599 - acc: 0.8459 - val_loss: 1.5453 - val_acc: 0.8622
# Epoch 192/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.5992 - acc: 0.8435 - val_loss: 1.4886 - val_acc: 0.8707
# Epoch 193/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.5593 - acc: 0.8460 - val_loss: 1.5190 - val_acc: 0.8563
# Epoch 194/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.5228 - acc: 0.8536 - val_loss: 1.6080 - val_acc: 0.8131
# Epoch 195/200
# 35/34 [==============================] - 5s 143ms/step - loss: 1.5680 - acc: 0.8496 - val_loss: 1.4950 - val_acc: 0.8595
# Epoch 196/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.5770 - acc: 0.8368 - val_loss: 1.4934 - val_acc: 0.8644
# Epoch 197/200
# 35/34 [==============================] - 5s 141ms/step - loss: 1.5693 - acc: 0.8430 - val_loss: 1.5945 - val_acc: 0.8261
# Epoch 198/200
# 35/34 [==============================] - 5s 140ms/step - loss: 1.5527 - acc: 0.8413 - val_loss: 1.5217 - val_acc: 0.8586
# Epoch 199/200
# 35/34 [==============================] - 5s 142ms/step - loss: 1.5986 - acc: 0.8301 - val_loss: 1.4961 - val_acc: 0.8689
# Epoch 200/200
# 35/34 [==============================] - 5s 139ms/step - loss: 1.5529 - acc: 0.8393 - val_loss: 1.4696 - val_acc: 0.8725

# %%
batch_size = 64

history = net.train_generator(BrodatzNumpyArrayIterator(X_train, y_train, [shift_generator, zoom_in_generator, zoom_out_generator, rotation_generator], batch_size=batch_size), steps_per_epoch=len(X_train)/batch_size*100, epochs=100)

# %%
accuracies = [net.accuracy(X_test, y_test) for X_test, y_test, _ in [(X_train, y_train, num_classes)] + test_list]

# %%
accuracies
# Out:
# [0.97117117117117113,
#  0.62747747747747751,
#  0.87927927927927929,
#  0.13153153153153152,
#  0.74594594594594599,
#  0.75315315315315312]

# %%
y_pred = net.predict(test_list[0][0])

# %%
np.max(y_pred, axis=0)

# %%
history = net.train(X_train, y_train, (X_val, y_val), epochs=100, batch_size=256, )

# %%
plot_history(history)

# %%
net.model.summary()

# %%
model_name = curr_date()

# %%
root_directory = '/home/stanislau/repository/machine-learning/brodatz/results/'
directory_name = root_directory + curr_date()

# %%
if not os.path.exists(directory_name):
    os.makedirs(directory_name)

# %%
model_json = net.model.to_json()
with open(directory_name + "/model.json", "w") as json_file:
    json_file.write(model_json)

# %%
utils.plot_model(net.model, to_file=directory_name + "/model.png", show_shapes=True)

# %%
accuracies = [net.accuracy(X_test, y_test) for X_test, y_test, _ in [(X_train, y_train, num_classes)] + test_list]

# %%
accuracies
