# %%
import numpy as np

from brodatz.data_utils import process_file, process_file_some_classes, read_some_classes, save_model, read_train_test_sets, save_history
# from brodatz.utils import probas_to_classes, accuracy, curr_date, try_args_generator, try_args, get_bottlebeck_features
from brodatz.utils import *
from brodatz.visualization_utils import plot_image, plot, plot_history, plot_confusion_matrix

from brodatz.models.keras_neural_net import KerasNeuralNetwork

from brodatz.brodatz_generator import *

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

from keras import regularizers, optimizers, utils
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())

import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
# remove prefixes
import os
path = '/mnt/82db778e-0496-450c-9b25-d1e50a90e476/data/data4stas/01_data_cls'
os.chdir(path)

# %%
train_filename = 'Alexander_cls_train.csv'
test_filenames = ['Alexander_cls_test.csv',
                  'Alexander_cls_test1.csv',
                  'Alexander_cls_test2.csv',
                  'Alexander_cls_test3.csv',
                  'Alexander_cls_test4.csv']
classes_range = np.arange(0, 111)
X_train, y_train, num_classes, X_val, y_val, test_list = read_train_test_sets(train_filename, test_filenames, classes_range)

# %%
X_val, y_val = test_list[0][:2]

# %%
batch_size = 64
nb_train_samples = 2000
nb_validation_samples = 1000

train_generator = brodatz_generator_3_channels(X_train, y_train, batch_size=batch_size)
val_generator = brodatz_generator_3_channels(X_val, y_val, batch_size=batch_size)

bottleneck_features_train, bottleneck_features_validation = get_bottlebeck_features(train_generator, val_generator, batch_size, nb_train_samples, nb_validation_samples)

# %%
for i in range(len(test_list)):
    test_list[i][0] = np.vstack((test_list[i][0].T,)*3).T

# %%
X_val = np.vstack((X_val.T,)*3).T

# %%
X_val.shape
# Out:
# (2220, 200, 200, 3)

# %%
rotation_ranges = [0, 45, 90, 135, 180]
shear_ranges = [0, 0.2, 0.25, 1/3, 0.5, 0.75, 1]
shift_ranges = [0, 0.15, 0.3, 0.4, 0.45]
horizontal_flips = [True, False]
vertical_flips = [True, False]
zoom_ranges = [0, 0.2, 0.35, 0.5, 0.7, [0.6, 0.7], [1.4, 1.5]]
fill_modes = ['reflect', 'nearest', 'wrap']
learning_rates = [0.001, 0.002, 0.005, 0.01]
regularization_strengths = [0.001, 0.01, 0.05, 0.1]

rotation_range = [0, 0, 0, 180]
shear_range = 0
shift_range = [0.5, 0.4, 0.3, 0.4]
horizontal_flip = True
vertical_flip = True
zoom_range = [0, [0.55, 0.65], [1.45, 1.55], 0]
fill_mode = 'reflect'
batch_size = 64
epochs = 100
learning_rate = 0.002
regularization_strength = 0.01

input_shape = X_train[0].shape
regularizer = regularizers.l2(regularization_strength)
optimizer = optimizers.SGD(lr=learning_rate, decay=0, momentum=0.9, nesterov=True)

net = KerasNeuralNetwork(input_shape, num_classes, regularizer=regularizer, optimizer=optimizer)
net.compile_model_finetuning()

datagen = brodatz_generator(X_train, y_train, batch_size)

steps_per_epoch = len(X_train) / batch_size * 4

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)
model_checkpoint = ModelCheckpoint('/home/stanislau/repository/machine-learning/brodatz/results/28.11.2017 11:24:8/best_model.h5', monitor='val_acc', verbose=0, save_best_only=True, save_weights_only=True, mode='auto', period=1)
callbacks = [reduce_lr]
callbacks = None

callbacks = [model_checkpoint]

# try_args_fit(bottleneck_features_train, y_train, num_classes, X_val, y_val, test_list, net, optimizer, callbacks, rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs, learning_rate, regularization_strength, save_model=False, save_results=False)

try_args_generator(X_train, y_train, num_classes, X_val, y_val, test_list, net, optimizer, datagen, steps_per_epoch, callbacks, rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs, learning_rate, regularization_strength)

# for rotation_range in rotation_ranges:
#     try_args(rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs)

# for shear_range in shear_ranges:
#     try_args(rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs)
# Out:
# Epoch 1/100
# 35/34 [==============================] - 24s 685ms/step - loss: 0.3083 - acc: 0.9714 - val_loss: 0.3764 - val_acc: 0.9464
# Epoch 2/100
# 35/34 [==============================] - 16s 449ms/step - loss: 0.3083 - acc: 0.9703 - val_loss: 0.3964 - val_acc: 0.9360
# Epoch 3/100
# 35/34 [==============================] - 17s 493ms/step - loss: 0.3030 - acc: 0.9748 - val_loss: 0.3880 - val_acc: 0.9437
# Epoch 4/100
# 35/34 [==============================] - 17s 487ms/step - loss: 0.3035 - acc: 0.9715 - val_loss: 0.3927 - val_acc: 0.9356
# Epoch 5/100
# 35/34 [==============================] - 16s 447ms/step - loss: 0.3109 - acc: 0.9742 - val_loss: 0.3938 - val_acc: 0.9387
# Epoch 6/100
# 35/34 [==============================] - 16s 447ms/step - loss: 0.3030 - acc: 0.9786 - val_loss: 0.4050 - val_acc: 0.9261
# Epoch 7/100
# 35/34 [==============================] - 16s 459ms/step - loss: 0.2979 - acc: 0.9775 - val_loss: 0.4057 - val_acc: 0.9342
# Epoch 8/100
# 35/34 [==============================] - 16s 452ms/step - loss: 0.2992 - acc: 0.9763 - val_loss: 0.3854 - val_acc: 0.9450
# Epoch 9/100
# 35/34 [==============================] - 17s 473ms/step - loss: 0.3079 - acc: 0.9699 - val_loss: 0.4004 - val_acc: 0.9320
# Epoch 10/100
# 35/34 [==============================] - 16s 448ms/step - loss: 0.3106 - acc: 0.9699 - val_loss: 0.3925 - val_acc: 0.9378
# Epoch 11/100
# 35/34 [==============================] - 16s 459ms/step - loss: 0.2959 - acc: 0.9793 - val_loss: 0.4079 - val_acc: 0.9315
# Epoch 12/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.3105 - acc: 0.9690 - val_loss: 0.3984 - val_acc: 0.9365
# Epoch 13/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.3081 - acc: 0.9735 - val_loss: 0.4077 - val_acc: 0.9297
# Epoch 14/100
# 35/34 [==============================] - 16s 444ms/step - loss: 0.3073 - acc: 0.9721 - val_loss: 0.4067 - val_acc: 0.9320
# Epoch 15/100
# 35/34 [==============================] - 16s 454ms/step - loss: 0.3024 - acc: 0.9768 - val_loss: 0.3920 - val_acc: 0.9347
# Epoch 16/100
# 35/34 [==============================] - 16s 454ms/step - loss: 0.2940 - acc: 0.9759 - val_loss: 0.3715 - val_acc: 0.9482
# Epoch 17/100
# 35/34 [==============================] - 16s 449ms/step - loss: 0.3042 - acc: 0.9730 - val_loss: 0.3834 - val_acc: 0.9419
# Epoch 18/100
# 35/34 [==============================] - 17s 485ms/step - loss: 0.3025 - acc: 0.9754 - val_loss: 0.3721 - val_acc: 0.9464
# Epoch 19/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.2964 - acc: 0.9735 - val_loss: 0.3955 - val_acc: 0.9383
# Epoch 20/100
# 35/34 [==============================] - 16s 444ms/step - loss: 0.2961 - acc: 0.9768 - val_loss: 0.3756 - val_acc: 0.9414
# Epoch 21/100
# 35/34 [==============================] - 16s 452ms/step - loss: 0.2958 - acc: 0.9728 - val_loss: 0.3969 - val_acc: 0.9333
# Epoch 22/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.2930 - acc: 0.9782 - val_loss: 0.4067 - val_acc: 0.9369
# Epoch 23/100
# 35/34 [==============================] - 16s 448ms/step - loss: 0.3012 - acc: 0.9723 - val_loss: 0.3835 - val_acc: 0.9432
# Epoch 24/100
# 35/34 [==============================] - 16s 450ms/step - loss: 0.3032 - acc: 0.9730 - val_loss: 0.3812 - val_acc: 0.9441
# Epoch 25/100
# 35/34 [==============================] - 16s 451ms/step - loss: 0.2994 - acc: 0.9732 - val_loss: 0.4037 - val_acc: 0.9288
# Epoch 26/100
# 35/34 [==============================] - 16s 450ms/step - loss: 0.3065 - acc: 0.9710 - val_loss: 0.3939 - val_acc: 0.9419
# Epoch 27/100
# 35/34 [==============================] - 16s 449ms/step - loss: 0.2951 - acc: 0.9797 - val_loss: 0.4067 - val_acc: 0.9320
# Epoch 28/100
# 35/34 [==============================] - 18s 523ms/step - loss: 0.2914 - acc: 0.9790 - val_loss: 0.3969 - val_acc: 0.9383
# Epoch 29/100
# 35/34 [==============================] - 16s 449ms/step - loss: 0.3039 - acc: 0.9721 - val_loss: 0.4021 - val_acc: 0.9338
# Epoch 30/100
# 35/34 [==============================] - 16s 451ms/step - loss: 0.3008 - acc: 0.9763 - val_loss: 0.3864 - val_acc: 0.9333
# Epoch 31/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.3000 - acc: 0.9721 - val_loss: 0.3764 - val_acc: 0.9401
# Epoch 32/100
# 35/34 [==============================] - 16s 451ms/step - loss: 0.2957 - acc: 0.9755 - val_loss: 0.3913 - val_acc: 0.9378
# Epoch 33/100
# 35/34 [==============================] - 16s 456ms/step - loss: 0.2935 - acc: 0.9754 - val_loss: 0.3959 - val_acc: 0.9347
# Epoch 34/100
# 35/34 [==============================] - 16s 448ms/step - loss: 0.3054 - acc: 0.9685 - val_loss: 0.3866 - val_acc: 0.9347
# Epoch 35/100
# 35/34 [==============================] - 16s 460ms/step - loss: 0.3053 - acc: 0.9710 - val_loss: 0.3974 - val_acc: 0.9351
# Epoch 36/100
# 35/34 [==============================] - 15s 442ms/step - loss: 0.3012 - acc: 0.9721 - val_loss: 0.3853 - val_acc: 0.9374
# Epoch 37/100
# 35/34 [==============================] - 16s 444ms/step - loss: 0.2996 - acc: 0.9701 - val_loss: 0.4025 - val_acc: 0.9288
# Epoch 38/100
# 35/34 [==============================] - 16s 444ms/step - loss: 0.2978 - acc: 0.9768 - val_loss: 0.3873 - val_acc: 0.9360
# Epoch 39/100
# 35/34 [==============================] - 15s 443ms/step - loss: 0.2991 - acc: 0.9777 - val_loss: 0.3923 - val_acc: 0.9329
# Epoch 40/100
# 35/34 [==============================] - 16s 445ms/step - loss: 0.3008 - acc: 0.9735 - val_loss: 0.3914 - val_acc: 0.9329
# Epoch 41/100
# 35/34 [==============================] - 16s 449ms/step - loss: 0.2898 - acc: 0.9808 - val_loss: 0.3847 - val_acc: 0.9468
# Epoch 42/100
# 35/34 [==============================] - 15s 443ms/step - loss: 0.2995 - acc: 0.9744 - val_loss: 0.3872 - val_acc: 0.9419
# Epoch 43/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.3052 - acc: 0.9701 - val_loss: 0.3741 - val_acc: 0.9432
# Epoch 44/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.2978 - acc: 0.9724 - val_loss: 0.3812 - val_acc: 0.9432
# Epoch 45/100
# 35/34 [==============================] - 16s 444ms/step - loss: 0.3067 - acc: 0.9682 - val_loss: 0.3912 - val_acc: 0.9401
# Epoch 46/100
# 35/34 [==============================] - 16s 444ms/step - loss: 0.3011 - acc: 0.9772 - val_loss: 0.3934 - val_acc: 0.9419
# Epoch 47/100
# 35/34 [==============================] - 16s 443ms/step - loss: 0.3022 - acc: 0.9694 - val_loss: 0.3876 - val_acc: 0.9369
# Epoch 48/100
# 35/34 [==============================] - 16s 443ms/step - loss: 0.2987 - acc: 0.9748 - val_loss: 0.3789 - val_acc: 0.9432
# Epoch 49/100
# 35/34 [==============================] - 15s 440ms/step - loss: 0.2865 - acc: 0.9808 - val_loss: 0.4003 - val_acc: 0.9284
# Epoch 50/100
# 35/34 [==============================] - 15s 441ms/step - loss: 0.2917 - acc: 0.9761 - val_loss: 0.3911 - val_acc: 0.9419
# Epoch 51/100
# 35/34 [==============================] - 15s 442ms/step - loss: 0.2874 - acc: 0.9768 - val_loss: 0.3919 - val_acc: 0.9329
# Epoch 52/100
# 35/34 [==============================] - 16s 443ms/step - loss: 0.2880 - acc: 0.9779 - val_loss: 0.3883 - val_acc: 0.9360
# Epoch 53/100
# 35/34 [==============================] - 15s 443ms/step - loss: 0.3035 - acc: 0.9679 - val_loss: 0.4028 - val_acc: 0.9306
# Epoch 54/100
# 35/34 [==============================] - 15s 441ms/step - loss: 0.2926 - acc: 0.9752 - val_loss: 0.3699 - val_acc: 0.9396
# Epoch 55/100
# 35/34 [==============================] - 16s 448ms/step - loss: 0.2957 - acc: 0.9733 - val_loss: 0.3804 - val_acc: 0.9464
# Epoch 56/100
# 35/34 [==============================] - 15s 442ms/step - loss: 0.2965 - acc: 0.9745 - val_loss: 0.3776 - val_acc: 0.9441
# Epoch 57/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.2936 - acc: 0.9738 - val_loss: 0.3615 - val_acc: 0.9518
# Epoch 58/100
# 35/34 [==============================] - 15s 441ms/step - loss: 0.2893 - acc: 0.9784 - val_loss: 0.4129 - val_acc: 0.9252
# Epoch 59/100
# 35/34 [==============================] - 16s 450ms/step - loss: 0.3060 - acc: 0.9705 - val_loss: 0.3804 - val_acc: 0.9419
# Epoch 60/100
# 35/34 [==============================] - 15s 441ms/step - loss: 0.2969 - acc: 0.9728 - val_loss: 0.3835 - val_acc: 0.9396
# Epoch 61/100
# 35/34 [==============================] - 15s 442ms/step - loss: 0.2976 - acc: 0.9759 - val_loss: 0.3958 - val_acc: 0.9374
# Epoch 62/100
# 35/34 [==============================] - 16s 448ms/step - loss: 0.2987 - acc: 0.9745 - val_loss: 0.4019 - val_acc: 0.9324
# Epoch 63/100
# 35/34 [==============================] - 16s 445ms/step - loss: 0.2955 - acc: 0.9730 - val_loss: 0.3993 - val_acc: 0.9315
# Epoch 64/100
# 35/34 [==============================] - 15s 442ms/step - loss: 0.2908 - acc: 0.9748 - val_loss: 0.3985 - val_acc: 0.9315
# Epoch 65/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.3001 - acc: 0.9710 - val_loss: 0.3956 - val_acc: 0.9356
# Epoch 66/100
# 35/34 [==============================] - 16s 448ms/step - loss: 0.2897 - acc: 0.9744 - val_loss: 0.3766 - val_acc: 0.9455
# Epoch 67/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.2973 - acc: 0.9739 - val_loss: 0.3824 - val_acc: 0.9369
# Epoch 68/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.2912 - acc: 0.9743 - val_loss: 0.3876 - val_acc: 0.9392
# Epoch 69/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.2928 - acc: 0.9748 - val_loss: 0.3769 - val_acc: 0.9405
# Epoch 70/100
# 35/34 [==============================] - 16s 449ms/step - loss: 0.2952 - acc: 0.9717 - val_loss: 0.4055 - val_acc: 0.9270
# Epoch 71/100
# 35/34 [==============================] - 16s 445ms/step - loss: 0.2915 - acc: 0.9772 - val_loss: 0.3817 - val_acc: 0.9387
# Epoch 72/100
# 35/34 [==============================] - 16s 444ms/step - loss: 0.2914 - acc: 0.9754 - val_loss: 0.3781 - val_acc: 0.9441
# Epoch 73/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.2886 - acc: 0.9775 - val_loss: 0.3801 - val_acc: 0.9396
# Epoch 74/100
# 35/34 [==============================] - 16s 443ms/step - loss: 0.2864 - acc: 0.9779 - val_loss: 0.3889 - val_acc: 0.9347
# Epoch 75/100
# 35/34 [==============================] - 16s 448ms/step - loss: 0.2982 - acc: 0.9737 - val_loss: 0.3767 - val_acc: 0.9351
# Epoch 76/100
# 35/34 [==============================] - 16s 444ms/step - loss: 0.2951 - acc: 0.9733 - val_loss: 0.4010 - val_acc: 0.9338
# Epoch 77/100
# 35/34 [==============================] - 16s 444ms/step - loss: 0.2955 - acc: 0.9723 - val_loss: 0.3860 - val_acc: 0.9351
# Epoch 78/100
# 35/34 [==============================] - 16s 454ms/step - loss: 0.2874 - acc: 0.9770 - val_loss: 0.3757 - val_acc: 0.9419
# Epoch 79/100
# 35/34 [==============================] - 16s 460ms/step - loss: 0.2869 - acc: 0.9769 - val_loss: 0.3773 - val_acc: 0.9419
# Epoch 80/100
# 35/34 [==============================] - 16s 447ms/step - loss: 0.2872 - acc: 0.9746 - val_loss: 0.3679 - val_acc: 0.9495
# Epoch 81/100
# 35/34 [==============================] - 16s 447ms/step - loss: 0.2791 - acc: 0.9822 - val_loss: 0.3949 - val_acc: 0.9378
# Epoch 82/100
# 35/34 [==============================] - 16s 450ms/step - loss: 0.2941 - acc: 0.9742 - val_loss: 0.3799 - val_acc: 0.9414
# Epoch 83/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.2820 - acc: 0.9799 - val_loss: 0.3818 - val_acc: 0.9396
# Epoch 84/100
# 35/34 [==============================] - 16s 447ms/step - loss: 0.2989 - acc: 0.9686 - val_loss: 0.3684 - val_acc: 0.9455
# Epoch 85/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.2943 - acc: 0.9748 - val_loss: 0.3855 - val_acc: 0.9338
# Epoch 86/100
# 35/34 [==============================] - 16s 445ms/step - loss: 0.2891 - acc: 0.9754 - val_loss: 0.3785 - val_acc: 0.9392
# Epoch 87/100
# 35/34 [==============================] - 16s 445ms/step - loss: 0.2953 - acc: 0.9726 - val_loss: 0.3993 - val_acc: 0.9338
# Epoch 88/100
# 35/34 [==============================] - 16s 445ms/step - loss: 0.2947 - acc: 0.9699 - val_loss: 0.3883 - val_acc: 0.9392
# Epoch 89/100
# 35/34 [==============================] - 15s 443ms/step - loss: 0.2814 - acc: 0.9766 - val_loss: 0.3680 - val_acc: 0.9423
# Epoch 90/100
# 35/34 [==============================] - 16s 445ms/step - loss: 0.2868 - acc: 0.9748 - val_loss: 0.3752 - val_acc: 0.9455
# Epoch 91/100
# 35/34 [==============================] - 16s 445ms/step - loss: 0.2899 - acc: 0.9699 - val_loss: 0.3987 - val_acc: 0.9302
# Epoch 92/100
# 35/34 [==============================] - 16s 444ms/step - loss: 0.2871 - acc: 0.9770 - val_loss: 0.3788 - val_acc: 0.9387
# Epoch 93/100
# 35/34 [==============================] - 16s 445ms/step - loss: 0.2926 - acc: 0.9726 - val_loss: 0.3726 - val_acc: 0.9360
# Epoch 94/100
# 35/34 [==============================] - 16s 447ms/step - loss: 0.2815 - acc: 0.9795 - val_loss: 0.3702 - val_acc: 0.9414
# Epoch 95/100
# 35/34 [==============================] - 16s 448ms/step - loss: 0.2854 - acc: 0.9779 - val_loss: 0.3740 - val_acc: 0.9392
# Epoch 96/100
# 35/34 [==============================] - 16s 443ms/step - loss: 0.2742 - acc: 0.9768 - val_loss: 0.3749 - val_acc: 0.9405
# Epoch 97/100
# 35/34 [==============================] - 16s 447ms/step - loss: 0.2836 - acc: 0.9777 - val_loss: 0.3799 - val_acc: 0.9387
# Epoch 98/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.2928 - acc: 0.9719 - val_loss: 0.3813 - val_acc: 0.9347
# Epoch 99/100
# 35/34 [==============================] - 16s 445ms/step - loss: 0.2930 - acc: 0.9759 - val_loss: 0.3701 - val_acc: 0.9428
# Epoch 100/100
# 35/34 [==============================] - 16s 446ms/step - loss: 0.2935 - acc: 0.9708 - val_loss: 0.3861 - val_acc: 0.9387

# %%
net = KerasNeuralNetwork(input_shape, num_classes, regularizer=regularizer, optimizer=optimizer)
net.compile_model_finetuning()

# %%
net.model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 200, 200, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 200, 200, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 200, 200, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 100, 100, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 100, 100, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 100, 100, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 50, 50, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 50, 50, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 25, 25, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 25, 25, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 12, 12, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               4718848
# _________________________________________________________________
# dense_14 (Dense)             (None, 111)               28527
# =================================================================
# Total params: 19,462,063
# Trainable params: 4,747,375
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
rotation_ranges = [0, 45, 90, 135, 180]
shear_ranges = [0, 0.2, 0.25, 1/3, 0.5, 0.75, 1]
shift_ranges = [0, 0.15, 0.3, 0.4, 0.45]
horizontal_flips = [True, False]
vertical_flips = [True, False]
zoom_ranges = [0, 0.2, 0.35, 0.5, 0.7, [0.6, 0.7], [1.4, 1.5]]
fill_modes = ['reflect', 'nearest', 'wrap']
learning_rates = [0.001, 0.002, 0.005, 0.01]
regularization_strengths = [0.001, 0.01, 0.05, 0.1]

rotation_range = 180
shear_range = 0
shift_range = 0.4
horizontal_flip = True
vertical_flip = True
zoom_range = [0.5, 1.6]
fill_mode = 'reflect'

batch_size = 64
epochs = 1000
learning_rate = 0.002
regularization_strength = 0.01

input_shape = X_train[0].shape
regularizer = regularizers.l2(regularization_strength)
optimizer = optimizers.SGD(lr=learning_rate, decay=1e-6, momentum=0.9, nesterov=True)

net = KerasNeuralNetwork(input_shape, num_classes, regularizer=regularizer, optimizer=optimizer)
net.compile_model_3()

datagen = ImageDataGenerator(
    rotation_range=rotation_range,
    width_shift_range=shift_range,
    height_shift_range=shift_range,
    horizontal_flip=horizontal_flip,
    vertical_flip=vertical_flip,
    zoom_range=zoom_range,
    fill_mode=fill_mode)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)

try_args(X_train, y_train, num_classes, X_val, y_val, test_list, net, optimizer, datagen, rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs, learning_rate, regularization_strength)

# try_args_generator(X_train, y_train, num_classes, X_val, y_val, test_list, net, optimizer, datagen, steps_per_epoch, [reduce_lr], rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs, learning_rate, regularization_strength)

# for rotation_range in rotation_ranges:
#     try_args(rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs)

# for shear_range in shear_ranges:
#     try_args(rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs)

# %%
net.model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_40 (Conv2D)           (None, 196, 196, 32)      832
# _________________________________________________________________
# activation_28 (Activation)   (None, 196, 196, 32)      0
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 98, 98, 32)        0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 96, 96, 64)        18496
# _________________________________________________________________
# activation_29 (Activation)   (None, 96, 96, 64)        0
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 46, 46, 128)       73856
# _________________________________________________________________
# activation_30 (Activation)   (None, 46, 46, 128)       0
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 23, 23, 128)       0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 67712)             0
# _________________________________________________________________
# dense_14 (Dense)             (None, 111)               7516143
# =================================================================
# Total params: 7,609,327
# Trainable params: 7,609,327
# Non-trainable params: 0
# _________________________________________________________________
