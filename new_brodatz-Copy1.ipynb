# %%
import numpy as np

from brodatz.data_utils import process_file, process_file_some_classes, read_some_classes, save_model, read_train_test_sets, save_history
from brodatz.utils import probas_to_classes, accuracy, curr_date
from brodatz.visualization_utils import plot_image, plot, plot_history, plot_confusion_matrix, plot_inputs

from brodatz.models.keras_neural_net import KerasNeuralNetwork

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

from keras import regularizers, optimizers, utils
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())

import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
# remove prefixes
import os
path = '/mnt/82db778e-0496-450c-9b25-d1e50a90e476/data/data4stas/01_data_cls'
os.chdir(path)

# %%
classes_range = np.arange(0, 20)
X_train, y_train, num_classes = process_file_some_classes('Alexander_cls_train.csv', classes_range)

# %%
classes_range = np.arange(0, 20)
X_train, y_train, num_classes = read_some_classes('Alexander_cls_train.csv', classes_range)

# %%
plot_image(X_mean)

# %%
plot_image(X_train[10])

# %%
classes_range = np.arange(0, 20)
X_train, y_train, num_classes = read_some_classes('Alexander_cls_train.csv', classes_range)
X_test, y_test, num_classes = read_some_classes('Alexander_cls_test.csv', classes_range)

X_train = X_train.astype('float') / 255
X_mean = np.mean(X_train, axis=0)
# X_std = np.std(X_train, axis=0)
# X_train = (X_train - X_mean) / (X_std + 1e-7)
X_train -= X_mean

X_test = X_test.astype('float') / 255
# X_test = (X_test - X_mean) / (X_std + 1e-7)
X_test -= X_mean
X_test = X_test[..., np.newaxis]

y_train = utils.to_categorical(y_train, num_classes=num_classes)
X_train = X_train[..., np.newaxis]

mask = np.random.permutation(len(X_test))
# X_train = X_train[mask]
# y_train = y_train[mask]
num_train = round(len(X_test) * 0.8)
X_val = X_test[num_train:]
y_val = y_test[num_train:]
y_val = utils.to_categorical(y_val, num_classes=num_classes)

# num_train = round(len(X_train) * 0.8)
# X_val = X_train[num_train:]
# y_val = y_train[num_train:]
# X_train = X_train[:num_train]
# y_train = y_train[:num_train]

# %%
train_filename = 'Alexander_cls_train.csv'
test_filenames = ['Alexander_cls_test.csv',
                  'Alexander_cls_test1.csv',
                  'Alexander_cls_test2.csv',
                  'Alexander_cls_test3.csv',
                  'Alexander_cls_test4.csv']
classes_range = np.arange(0, 111)
X_train, y_train, num_classes, X_val, y_val, test_list = read_train_test_sets(train_filename, test_filenames, classes_range)

# %%
X_train.shape
# Out:
# (100, 200, 200, 1)

# %%
class_number = 12
mask = np.argmax(y_train, axis=1) == class_number
X_train_cls = X_train[mask]

test_list_cls = [test[0][np.argmax(test[1], axis=1) == class_number] for test in test_list]
test_list_cls = [X_train_cls] + test_list_cls[1:]

# %%
plot_inputs(test_list_cls)

# %%
X_val, y_val = test_list[3][:2]

# %%
rotation_range = 0
shear_range = 0
shift_range = 0.4
horizontal_flip = True
vertical_flip = True
# zoom_range = [0.6, 0.7]
zoom_range = [1.4, 1.5]
fill_mode = 'reflect'

datagen = ImageDataGenerator(
    rotation_range=rotation_range,
    shear_range=np.pi * shear_range,
    width_shift_range=shift_range,
    height_shift_range=shift_range,
    horizontal_flip=horizontal_flip,
    vertical_flip=vertical_flip,
    zoom_range=zoom_range,
    fill_mode=fill_mode)

batch_list = []
i = 0
for batch in datagen.flow(X_train_cls, batch_size=5):
    batch_list.append(batch)
    i += 1
    if i % 5 == 0:
        break
    
plot_inputs(batch_list)

# %%
batch_list[0].shape
# Out:
# (5, 200, 200, 1)

# %%
import json
import pandas as pd
import datetime

def try_args(rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode,
             batch_size, epochs, learning_rate, regularization_strength):
    input_shape = X_train[0].shape
    
    learning_rate = learning_rate
    regularizer = regularizers.l2(regularization_strength)
    optimizer = optimizers.SGD(lr=learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
   
    net = KerasNeuralNetwork(input_shape, num_classes, regularizer=regularizer, optimizer=optimizer)
    net.compile_model_3()
    
    datagen = ImageDataGenerator(
        rotation_range=rotation_range,
        shear_range=np.pi * shear_range,
        width_shift_range=shift_range,
        height_shift_range=shift_range,
        horizontal_flip=horizontal_flip,
        vertical_flip=vertical_flip,
        zoom_range=zoom_range,
        fill_mode=fill_mode)
    
    train_start = datetime.datetime.now()
    history = net.train(datagen, X_train, y_train, (X_val, y_val), epochs=epochs, batch_size=batch_size,)
    train_finish = datetime.datetime.now()
    train_duration = (train_finish - train_start).seconds
    
    model_name = curr_date() # name of the directory for model
    root_directory = '/home/stanislau/repository/machine-learning/brodatz/results/'
    directory_name = root_directory + curr_date()
    if not os.path.exists(directory_name):
        os.makedirs(directory_name) # create directory
        
    save_history(directory_name + '/loss.png', directory_name + '/accuracy.png', history) # save plots of loss and accuracy
        
    model_json = net.model.to_json()
    with open(directory_name + "/model.json", "w") as json_file:
        json_file.write(model_json) # save model to file
        
    utils.plot_model(net.model, to_file=directory_name + "/model.png", show_shapes=True) # save model png overview to file
    
    count_params = net.model.count_params() # number of model parameters
    optimizer_json = json.dumps(optimizers.serialize(optimizer))
    with open(directory_name + "/optimizer.json", "w") as json_file:
        json_file.write(optimizer_json) # save optimizer to file

    models_battles_filename = root_directory + 'models_battles.csv'
    header = ['Model name', 'X_train', 'X_test', 'X_test1', 'X_test2', 'X_test3', 'X_test4',
              'Epochs', 'Number of parameters', 'Batches', 'Learning rate', 'Train duration',
              'Rotation range', 'Shear range', 'Shift range', 'Hor flip', 'Ver flip', 'Zoom range', 'Fill mode',
              'Number of classes',
              'Regularization Strength']
    accuracies = [net.accuracy(X_test, y_test) for X_test, y_test, _ in [(X_train, y_train, num_classes)] + test_list]
    data = [model_name]
    data.extend(accuracies)
    number_of_params = net.model.count_params()
    data.extend([epochs, number_of_params, batch_size, learning_rate, train_duration])
    data.extend([rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode])
    data.append(num_classes)
    data.append(regularization_strength)
    if not os.path.isfile(models_battles_filename):
        df = pd.DataFrame([data], columns=header)
        df.to_csv(models_battles_filename)
    else:
        with open(models_battles_filename, 'a') as f:
            df = pd.DataFrame([data])
            df.to_csv(f, header=False)

rotation_ranges = [0, 45, 90, 135, 180]
shear_ranges = [0, 0.2, 0.25, 1/3, 0.5, 0.75, 1]
shift_ranges = [0, 0.15, 0.2, 0.3, 0.4, 0.45]
horizontal_flips = [True, False]
vertical_flips = [True, False]
zoom_ranges = [0, 0.2, 0.35, 0.5, 0.7, [0.6, 0.7], [1.4, 1.5]]
fill_modes = ['reflect', 'nearest', 'wrap']
learning_rates = [0.001, 0.002, 0.005, 0.01]
regularization_strengths = [0.001, 0.01, 0.05, 0.1]

rotation_range = rotation_ranges[0]
shear_range = shear_ranges[0]
shift_range = shift_ranges[2]
horizontal_flip = horizontal_flips[1]
vertical_flip = vertical_flips[1]
zoom_range = zoom_ranges[6]
fill_mode = fill_modes[0]
batch_size = 64
epochs = 250
learning_rate = learning_rates[2]
regularization_strength = regularization_strengths[1]

for zoom_range in zoom_ranges:
    for shift_range in shift_ranges:
        for flip in [True, False]:
            horizontal_flip = flip
            vertical_flip = flip
        
            try_args(rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs, learning_rate, regularization_strength)


# try_args(rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs, learning_rate, regularization_strength)

# for shear_range in shear_ranges:
#     try_args(rotation_range, shear_range, shift_range, horizontal_flip, vertical_flip, zoom_range, fill_mode, batch_size, epochs)
# Out:
# Epoch 1/250
# 9/8 [===============================] - 2s 208ms/step - loss: 8.2268 - acc: 0.0052 - val_loss: 8.1981 - val_acc: 0.0072
# Epoch 2/250
# 9/8 [===============================] - 1s 147ms/step - loss: 8.1775 - acc: 0.0070 - val_loss: 8.1411 - val_acc: 0.0126
# Epoch 3/250
# 9/8 [===============================] - 1s 154ms/step - loss: 8.1141 - acc: 0.0025 - val_loss: 8.0761 - val_acc: 0.0108
# Epoch 4/250
# 9/8 [===============================] - 1s 133ms/step - loss: 8.0446 - acc: 0.0130 - val_loss: 8.0082 - val_acc: 0.0090
# Epoch 5/250
# 9/8 [===============================] - 1s 153ms/step - loss: 7.9747 - acc: 0.0087 - val_loss: 7.9390 - val_acc: 0.0144
# Epoch 6/250
# 9/8 [===============================] - 1s 151ms/step - loss: 7.9042 - acc: 0.0139 - val_loss: 7.8684 - val_acc: 0.0288
# Epoch 7/250
# 9/8 [===============================] - 1s 164ms/step - loss: 7.8276 - acc: 0.0122 - val_loss: 7.7972 - val_acc: 0.0126
# Epoch 8/250
# 9/8 [===============================] - 1s 153ms/step - loss: 7.7546 - acc: 0.0139 - val_loss: 7.7228 - val_acc: 0.0144
# Epoch 9/250
# 9/8 [===============================] - 2s 168ms/step - loss: 7.6764 - acc: 0.0087 - val_loss: 7.6482 - val_acc: 0.0090
# Epoch 10/250
# 9/8 [===============================] - 1s 136ms/step - loss: 7.5946 - acc: 0.0095 - val_loss: 7.5695 - val_acc: 0.0108
# Epoch 11/250
# 9/8 [===============================] - 1s 163ms/step - loss: 7.5130 - acc: 0.0087 - val_loss: 7.4902 - val_acc: 0.0198
# Epoch 12/250
# 9/8 [===============================] - 1s 147ms/step - loss: 7.4273 - acc: 0.0122 - val_loss: 7.3985 - val_acc: 0.0108
# Epoch 13/250
# 9/8 [===============================] - 1s 152ms/step - loss: 7.3249 - acc: 0.0095 - val_loss: 7.3252 - val_acc: 0.0396
# Epoch 14/250
# 9/8 [===============================] - 1s 149ms/step - loss: 7.2125 - acc: 0.0209 - val_loss: 7.2091 - val_acc: 0.0685
# Epoch 15/250
# 9/8 [===============================] - 1s 150ms/step - loss: 7.0881 - acc: 0.0553 - val_loss: 7.0632 - val_acc: 0.0721
# Epoch 16/250
# 9/8 [===============================] - 1s 153ms/step - loss: 6.9231 - acc: 0.0640 - val_loss: 6.9097 - val_acc: 0.1063
# Epoch 17/250
# 9/8 [===============================] - 1s 167ms/step - loss: 6.7577 - acc: 0.0745 - val_loss: 6.7257 - val_acc: 0.0991
# Epoch 18/250
# 9/8 [===============================] - 1s 155ms/step - loss: 6.5952 - acc: 0.0760 - val_loss: 6.5834 - val_acc: 0.1171
# Epoch 19/250
# 9/8 [===============================] - 1s 145ms/step - loss: 6.4315 - acc: 0.0941 - val_loss: 6.4690 - val_acc: 0.0919
# Epoch 20/250
# 9/8 [===============================] - 1s 156ms/step - loss: 6.3164 - acc: 0.0937 - val_loss: 6.3869 - val_acc: 0.1009
# Epoch 21/250
# 9/8 [===============================] - 1s 151ms/step - loss: 6.1118 - acc: 0.1460 - val_loss: 6.1055 - val_acc: 0.1532
# Epoch 22/250
# 9/8 [===============================] - 1s 152ms/step - loss: 5.8848 - acc: 0.1777 - val_loss: 5.9390 - val_acc: 0.1766
# Epoch 23/250
# 9/8 [===============================] - 1s 149ms/step - loss: 5.8250 - acc: 0.1864 - val_loss: 7.7658 - val_acc: 0.0342
# Epoch 24/250
# 9/8 [===============================] - 1s 146ms/step - loss: 5.6736 - acc: 0.2210 - val_loss: 5.8175 - val_acc: 0.2450
# Epoch 25/250
# 9/8 [===============================] - 1s 147ms/step - loss: 5.1986 - acc: 0.3655 - val_loss: 5.5511 - val_acc: 0.2577
# Epoch 26/250
# 9/8 [===============================] - 1s 142ms/step - loss: 4.9193 - acc: 0.3931 - val_loss: 5.7055 - val_acc: 0.1982
# Epoch 27/250
# 9/8 [===============================] - 1s 155ms/step - loss: 4.8040 - acc: 0.4095 - val_loss: 5.1697 - val_acc: 0.3207
# Epoch 28/250
# 9/8 [===============================] - 1s 146ms/step - loss: 4.4716 - acc: 0.4803 - val_loss: 5.5515 - val_acc: 0.2432
# Epoch 29/250
# 9/8 [===============================] - 1s 144ms/step - loss: 4.4545 - acc: 0.4821 - val_loss: 5.2428 - val_acc: 0.3099
# Epoch 30/250
# 9/8 [===============================] - 1s 141ms/step - loss: 4.1070 - acc: 0.5433 - val_loss: 5.6092 - val_acc: 0.2306
# Epoch 31/250
# 9/8 [===============================] - 1s 147ms/step - loss: 4.0073 - acc: 0.5827 - val_loss: 5.3466 - val_acc: 0.3189
# Epoch 32/250
# 9/8 [===============================] - 1s 149ms/step - loss: 3.8995 - acc: 0.5884 - val_loss: 4.8798 - val_acc: 0.3874
# Epoch 33/250
# 9/8 [===============================] - 1s 153ms/step - loss: 3.5987 - acc: 0.7030 - val_loss: 4.7531 - val_acc: 0.4270
# Epoch 34/250
# 9/8 [===============================] - 1s 152ms/step - loss: 3.5324 - acc: 0.7110 - val_loss: 4.6171 - val_acc: 0.4432
# Epoch 35/250
# 9/8 [===============================] - 1s 146ms/step - loss: 3.2657 - acc: 0.7484 - val_loss: 4.8237 - val_acc: 0.4072
# Epoch 36/250
# 9/8 [===============================] - 1s 143ms/step - loss: 3.2469 - acc: 0.7426 - val_loss: 4.7452 - val_acc: 0.4270
# Epoch 37/250
# 9/8 [===============================] - 1s 151ms/step - loss: 3.1670 - acc: 0.7865 - val_loss: 4.6315 - val_acc: 0.4396
# Epoch 38/250
# 9/8 [===============================] - 1s 142ms/step - loss: 3.1641 - acc: 0.7880 - val_loss: 4.6953 - val_acc: 0.4126
# Epoch 39/250
# 9/8 [===============================] - 1s 152ms/step - loss: 2.9969 - acc: 0.8314 - val_loss: 4.2771 - val_acc: 0.5027
# Epoch 40/250
# 9/8 [===============================] - 1s 149ms/step - loss: 2.9656 - acc: 0.8094 - val_loss: 4.5956 - val_acc: 0.4324
# Epoch 41/250
# 9/8 [===============================] - 1s 143ms/step - loss: 2.9571 - acc: 0.8181 - val_loss: 4.1910 - val_acc: 0.5225
# Epoch 42/250
# 9/8 [===============================] - 1s 147ms/step - loss: 2.7865 - acc: 0.8637 - val_loss: 4.1671 - val_acc: 0.5243
# Epoch 43/250
# 9/8 [===============================] - 1s 146ms/step - loss: 2.8085 - acc: 0.8448 - val_loss: 4.4252 - val_acc: 0.4847
# Epoch 44/250
# 9/8 [===============================] - 1s 160ms/step - loss: 2.7573 - acc: 0.8570 - val_loss: 4.0726 - val_acc: 0.5532
# Epoch 45/250
# 9/8 [===============================] - 1s 151ms/step - loss: 2.5862 - acc: 0.9036 - val_loss: 4.0562 - val_acc: 0.5802
# Epoch 46/250
# 9/8 [===============================] - 1s 160ms/step - loss: 2.5346 - acc: 0.9228 - val_loss: 4.2614 - val_acc: 0.5369
# Epoch 47/250
# 9/8 [===============================] - 1s 141ms/step - loss: 2.7006 - acc: 0.8643 - val_loss: 4.2081 - val_acc: 0.5423
# Epoch 48/250
# 9/8 [===============================] - 1s 154ms/step - loss: 2.6714 - acc: 0.8802 - val_loss: 4.1801 - val_acc: 0.5495
# Epoch 49/250
# 9/8 [===============================] - 1s 156ms/step - loss: 2.5758 - acc: 0.9148 - val_loss: 4.3273 - val_acc: 0.5135
# Epoch 50/250
# 9/8 [===============================] - 1s 161ms/step - loss: 2.6024 - acc: 0.8821 - val_loss: 4.2149 - val_acc: 0.5495
# Epoch 51/250
# 9/8 [===============================] - 1s 163ms/step - loss: 2.5337 - acc: 0.8931 - val_loss: 4.1849 - val_acc: 0.5640
# Epoch 52/250
# 9/8 [===============================] - 1s 152ms/step - loss: 2.4293 - acc: 0.9272 - val_loss: 4.0554 - val_acc: 0.5622
# Epoch 53/250
# 9/8 [===============================] - 1s 150ms/step - loss: 2.4615 - acc: 0.9178 - val_loss: 4.2383 - val_acc: 0.5387
# Epoch 54/250
# 9/8 [===============================] - 1s 153ms/step - loss: 2.4810 - acc: 0.9003 - val_loss: 4.1290 - val_acc: 0.5117
# Epoch 55/250
# 9/8 [===============================] - 1s 153ms/step - loss: 2.3885 - acc: 0.9360 - val_loss: 3.9702 - val_acc: 0.5495
# Epoch 56/250
# 9/8 [===============================] - 1s 163ms/step - loss: 2.3217 - acc: 0.9357 - val_loss: 3.8661 - val_acc: 0.5640
# Epoch 57/250
# 9/8 [===============================] - 1s 153ms/step - loss: 2.3155 - acc: 0.9158 - val_loss: 4.0482 - val_acc: 0.5333
# Epoch 58/250
# 9/8 [===============================] - 1s 145ms/step - loss: 2.3464 - acc: 0.9247 - val_loss: 3.8844 - val_acc: 0.5946
# Epoch 59/250
# 9/8 [===============================] - 1s 157ms/step - loss: 2.3312 - acc: 0.9195 - val_loss: 3.8808 - val_acc: 0.5495
# Epoch 60/250
# 9/8 [===============================] - 1s 154ms/step - loss: 2.2292 - acc: 0.9297 - val_loss: 4.0546 - val_acc: 0.5243
# Epoch 61/250
# 9/8 [===============================] - 1s 155ms/step - loss: 2.1940 - acc: 0.9385 - val_loss: 3.9133 - val_acc: 0.5676
# Epoch 62/250
# 9/8 [===============================] - 1s 153ms/step - loss: 2.1974 - acc: 0.9377 - val_loss: 3.8652 - val_acc: 0.5802
# Epoch 63/250
# 9/8 [===============================] - 2s 167ms/step - loss: 2.1860 - acc: 0.9243 - val_loss: 3.8036 - val_acc: 0.5694
# Epoch 64/250
# 9/8 [===============================] - 1s 150ms/step - loss: 2.1438 - acc: 0.9392 - val_loss: 3.6611 - val_acc: 0.5964
# Epoch 65/250
# 9/8 [===============================] - 1s 145ms/step - loss: 2.0686 - acc: 0.9497 - val_loss: 3.8014 - val_acc: 0.5802
# Epoch 66/250
# 9/8 [===============================] - 1s 151ms/step - loss: 2.0427 - acc: 0.9592 - val_loss: 3.7304 - val_acc: 0.5748
# Epoch 67/250
# 9/8 [===============================] - 1s 158ms/step - loss: 2.0407 - acc: 0.9534 - val_loss: 3.7083 - val_acc: 0.5910
# Epoch 68/250
# 9/8 [===============================] - 1s 156ms/step - loss: 2.0371 - acc: 0.9447 - val_loss: 3.8757 - val_acc: 0.5423
# Epoch 69/250
# 9/8 [===============================] - 1s 157ms/step - loss: 2.0150 - acc: 0.9305 - val_loss: 3.9359 - val_acc: 0.5459
# Epoch 70/250
# 9/8 [===============================] - 1s 145ms/step - loss: 2.2175 - acc: 0.8966 - val_loss: 4.0292 - val_acc: 0.5081
# Epoch 71/250
# 9/8 [===============================] - 1s 161ms/step - loss: 2.0396 - acc: 0.9263 - val_loss: 3.7318 - val_acc: 0.5351
# Epoch 72/250
# 9/8 [===============================] - 1s 152ms/step - loss: 1.9768 - acc: 0.9445 - val_loss: 3.5525 - val_acc: 0.5730
# Epoch 73/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.9304 - acc: 0.9549 - val_loss: 3.5158 - val_acc: 0.6072
# Epoch 74/250
# 9/8 [===============================] - 1s 152ms/step - loss: 1.8840 - acc: 0.9539 - val_loss: 3.4561 - val_acc: 0.5982
# Epoch 75/250
# 9/8 [===============================] - 1s 160ms/step - loss: 1.8472 - acc: 0.9592 - val_loss: 3.6302 - val_acc: 0.5712
# Epoch 76/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.8434 - acc: 0.9497 - val_loss: 3.5267 - val_acc: 0.5820
# Epoch 77/250
# 9/8 [===============================] - 1s 151ms/step - loss: 1.8496 - acc: 0.9385 - val_loss: 3.4941 - val_acc: 0.5784
# Epoch 78/250
# 9/8 [===============================] - 1s 157ms/step - loss: 1.8128 - acc: 0.9592 - val_loss: 3.3656 - val_acc: 0.6216
# Epoch 79/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.8016 - acc: 0.9456 - val_loss: 3.4072 - val_acc: 0.5964
# Epoch 80/250
# 9/8 [===============================] - 1s 159ms/step - loss: 1.7922 - acc: 0.9472 - val_loss: 3.5863 - val_acc: 0.5586
# Epoch 81/250
# 9/8 [===============================] - 1s 140ms/step - loss: 1.8027 - acc: 0.9474 - val_loss: 3.4208 - val_acc: 0.5640
# Epoch 82/250
# 9/8 [===============================] - 1s 158ms/step - loss: 1.7879 - acc: 0.9334 - val_loss: 3.4923 - val_acc: 0.5856
# Epoch 83/250
# 9/8 [===============================] - 1s 161ms/step - loss: 1.7755 - acc: 0.9365 - val_loss: 3.4739 - val_acc: 0.5730
# Epoch 84/250
# 9/8 [===============================] - 1s 143ms/step - loss: 1.7458 - acc: 0.9514 - val_loss: 3.3572 - val_acc: 0.5820
# Epoch 85/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.7015 - acc: 0.9512 - val_loss: 3.3425 - val_acc: 0.5946
# Epoch 86/250
# 9/8 [===============================] - 1s 153ms/step - loss: 1.7193 - acc: 0.9524 - val_loss: 3.3082 - val_acc: 0.5910
# Epoch 87/250
# 9/8 [===============================] - 1s 157ms/step - loss: 1.6932 - acc: 0.9594 - val_loss: 3.3206 - val_acc: 0.5748
# Epoch 88/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.6600 - acc: 0.9599 - val_loss: 3.1963 - val_acc: 0.6054
# Epoch 89/250
# 9/8 [===============================] - 1s 159ms/step - loss: 1.6622 - acc: 0.9524 - val_loss: 3.2742 - val_acc: 0.5892
# Epoch 90/250
# 9/8 [===============================] - 1s 165ms/step - loss: 1.6260 - acc: 0.9566 - val_loss: 3.3592 - val_acc: 0.5730
# Epoch 91/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.6297 - acc: 0.9534 - val_loss: 3.3951 - val_acc: 0.5586
# Epoch 92/250
# 9/8 [===============================] - 1s 164ms/step - loss: 1.6450 - acc: 0.9489 - val_loss: 3.3477 - val_acc: 0.5676
# Epoch 93/250
# 9/8 [===============================] - 1s 153ms/step - loss: 1.6137 - acc: 0.9514 - val_loss: 3.2863 - val_acc: 0.5892
# Epoch 94/250
# 9/8 [===============================] - 1s 152ms/step - loss: 1.5719 - acc: 0.9594 - val_loss: 3.2986 - val_acc: 0.5874
# Epoch 95/250
# 9/8 [===============================] - 1s 159ms/step - loss: 1.5586 - acc: 0.9619 - val_loss: 3.1865 - val_acc: 0.5910
# Epoch 96/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.5105 - acc: 0.9731 - val_loss: 3.2576 - val_acc: 0.5910
# Epoch 97/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.5272 - acc: 0.9611 - val_loss: 3.2312 - val_acc: 0.5946
# Epoch 98/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.5050 - acc: 0.9592 - val_loss: 3.1480 - val_acc: 0.5856
# Epoch 99/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.4792 - acc: 0.9671 - val_loss: 3.1943 - val_acc: 0.5748
# Epoch 100/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.4913 - acc: 0.9601 - val_loss: 3.1875 - val_acc: 0.6090
# Epoch 101/250
# 9/8 [===============================] - 1s 152ms/step - loss: 1.4633 - acc: 0.9617 - val_loss: 3.1079 - val_acc: 0.6144
# Epoch 102/250
# 9/8 [===============================] - 1s 160ms/step - loss: 1.4726 - acc: 0.9479 - val_loss: 3.1450 - val_acc: 0.6036
# Epoch 103/250
# 9/8 [===============================] - 1s 153ms/step - loss: 1.4577 - acc: 0.9584 - val_loss: 3.0485 - val_acc: 0.6216
# Epoch 104/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.4137 - acc: 0.9751 - val_loss: 3.1265 - val_acc: 0.6072
# Epoch 105/250
# 9/8 [===============================] - 1s 158ms/step - loss: 1.4294 - acc: 0.9654 - val_loss: 3.1006 - val_acc: 0.5892
# Epoch 106/250
# 9/8 [===============================] - 1s 157ms/step - loss: 1.4306 - acc: 0.9584 - val_loss: 3.0158 - val_acc: 0.6162
# Epoch 107/250
# 9/8 [===============================] - 1s 157ms/step - loss: 1.3888 - acc: 0.9617 - val_loss: 3.1704 - val_acc: 0.5838
# Epoch 108/250
# 9/8 [===============================] - 1s 152ms/step - loss: 1.3762 - acc: 0.9714 - val_loss: 3.0605 - val_acc: 0.6054
# Epoch 109/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.3792 - acc: 0.9696 - val_loss: 3.0046 - val_acc: 0.5982
# Epoch 110/250
# 9/8 [===============================] - 1s 152ms/step - loss: 1.3847 - acc: 0.9566 - val_loss: 3.2872 - val_acc: 0.5514
# Epoch 111/250
# 9/8 [===============================] - 2s 169ms/step - loss: 1.4326 - acc: 0.9479 - val_loss: 2.9932 - val_acc: 0.5802
# Epoch 112/250
# 9/8 [===============================] - 1s 160ms/step - loss: 1.3646 - acc: 0.9671 - val_loss: 2.9578 - val_acc: 0.6270
# Epoch 113/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.3531 - acc: 0.9559 - val_loss: 3.0940 - val_acc: 0.6000
# Epoch 114/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.3460 - acc: 0.9497 - val_loss: 3.1523 - val_acc: 0.5820
# Epoch 115/250
# 9/8 [===============================] - 1s 153ms/step - loss: 1.3124 - acc: 0.9671 - val_loss: 2.9581 - val_acc: 0.6180
# Epoch 116/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.3046 - acc: 0.9679 - val_loss: 3.0132 - val_acc: 0.6054
# Epoch 117/250
# 9/8 [===============================] - 1s 157ms/step - loss: 1.2979 - acc: 0.9594 - val_loss: 2.9740 - val_acc: 0.6090
# Epoch 118/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.2872 - acc: 0.9599 - val_loss: 2.9695 - val_acc: 0.6054
# Epoch 119/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.3204 - acc: 0.9638 - val_loss: 2.8775 - val_acc: 0.6126
# Epoch 120/250
# 9/8 [===============================] - 1s 160ms/step - loss: 1.2717 - acc: 0.9634 - val_loss: 2.9964 - val_acc: 0.5964
# Epoch 121/250
# 9/8 [===============================] - 1s 146ms/step - loss: 1.2537 - acc: 0.9714 - val_loss: 2.9109 - val_acc: 0.6216
# Epoch 122/250
# 9/8 [===============================] - 1s 159ms/step - loss: 1.2792 - acc: 0.9584 - val_loss: 2.9469 - val_acc: 0.6018
# Epoch 123/250
# 9/8 [===============================] - 1s 165ms/step - loss: 1.2900 - acc: 0.9495 - val_loss: 2.9086 - val_acc: 0.6054
# Epoch 124/250
# 9/8 [===============================] - 1s 148ms/step - loss: 1.2441 - acc: 0.9626 - val_loss: 2.9123 - val_acc: 0.6036
# Epoch 125/250
# 9/8 [===============================] - 1s 159ms/step - loss: 1.2353 - acc: 0.9626 - val_loss: 2.9511 - val_acc: 0.5982
# Epoch 126/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.2286 - acc: 0.9681 - val_loss: 2.9951 - val_acc: 0.5838
# Epoch 127/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.2520 - acc: 0.9576 - val_loss: 2.9631 - val_acc: 0.6018
# Epoch 128/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.1978 - acc: 0.9696 - val_loss: 2.8074 - val_acc: 0.6144
# Epoch 129/250
# 9/8 [===============================] - 1s 157ms/step - loss: 1.1830 - acc: 0.9671 - val_loss: 2.9570 - val_acc: 0.6054
# Epoch 130/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.1723 - acc: 0.9714 - val_loss: 2.8100 - val_acc: 0.6000
# Epoch 131/250
# 9/8 [===============================] - 1s 162ms/step - loss: 1.1796 - acc: 0.9721 - val_loss: 3.1157 - val_acc: 0.5820
# Epoch 132/250
# 9/8 [===============================] - 1s 151ms/step - loss: 1.2095 - acc: 0.9601 - val_loss: 2.9683 - val_acc: 0.6018
# Epoch 133/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.1770 - acc: 0.9594 - val_loss: 2.8637 - val_acc: 0.6072
# Epoch 134/250
# 9/8 [===============================] - 1s 158ms/step - loss: 1.1897 - acc: 0.9629 - val_loss: 2.9126 - val_acc: 0.5982
# Epoch 135/250
# 9/8 [===============================] - 1s 157ms/step - loss: 1.1725 - acc: 0.9654 - val_loss: 2.9032 - val_acc: 0.5856
# Epoch 136/250
# 9/8 [===============================] - 1s 153ms/step - loss: 1.1671 - acc: 0.9661 - val_loss: 2.8195 - val_acc: 0.6216
# Epoch 137/250
# 9/8 [===============================] - 1s 159ms/step - loss: 1.1550 - acc: 0.9592 - val_loss: 2.8551 - val_acc: 0.6054
# Epoch 138/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.2167 - acc: 0.9479 - val_loss: 2.8689 - val_acc: 0.5946
# Epoch 139/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.1696 - acc: 0.9609 - val_loss: 2.7670 - val_acc: 0.6054
# Epoch 140/250
# 9/8 [===============================] - 1s 146ms/step - loss: 1.1469 - acc: 0.9671 - val_loss: 2.8562 - val_acc: 0.5874
# Epoch 141/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.1243 - acc: 0.9696 - val_loss: 2.8241 - val_acc: 0.6000
# Epoch 142/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.1310 - acc: 0.9609 - val_loss: 2.8077 - val_acc: 0.5748
# Epoch 143/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.1327 - acc: 0.9646 - val_loss: 2.7791 - val_acc: 0.6162
# Epoch 144/250
# 9/8 [===============================] - 1s 158ms/step - loss: 1.1287 - acc: 0.9592 - val_loss: 2.7475 - val_acc: 0.6108
# Epoch 145/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.1003 - acc: 0.9679 - val_loss: 2.8354 - val_acc: 0.5946
# Epoch 146/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.0839 - acc: 0.9686 - val_loss: 2.6782 - val_acc: 0.6252
# Epoch 147/250
# 9/8 [===============================] - 1s 158ms/step - loss: 1.1053 - acc: 0.9663 - val_loss: 2.6819 - val_acc: 0.6216
# Epoch 148/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.1078 - acc: 0.9671 - val_loss: 2.7514 - val_acc: 0.5910
# Epoch 149/250
# 9/8 [===============================] - 1s 158ms/step - loss: 1.0809 - acc: 0.9731 - val_loss: 2.8221 - val_acc: 0.5964
# Epoch 150/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.0714 - acc: 0.9714 - val_loss: 2.6886 - val_acc: 0.6072
# Epoch 151/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.0773 - acc: 0.9584 - val_loss: 2.6266 - val_acc: 0.6054
# Epoch 152/250
# 9/8 [===============================] - 1s 162ms/step - loss: 1.0938 - acc: 0.9646 - val_loss: 2.7016 - val_acc: 0.6234
# Epoch 153/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.0861 - acc: 0.9594 - val_loss: 2.7325 - val_acc: 0.6000
# Epoch 154/250
# 9/8 [===============================] - 1s 151ms/step - loss: 1.0647 - acc: 0.9636 - val_loss: 2.7677 - val_acc: 0.6000
# Epoch 155/250
# 9/8 [===============================] - 1s 164ms/step - loss: 1.0600 - acc: 0.9706 - val_loss: 2.6096 - val_acc: 0.6252
# Epoch 156/250
# 9/8 [===============================] - 1s 150ms/step - loss: 1.0424 - acc: 0.9686 - val_loss: 2.6193 - val_acc: 0.6505
# Epoch 157/250
# 9/8 [===============================] - 1s 153ms/step - loss: 1.0257 - acc: 0.9721 - val_loss: 2.6656 - val_acc: 0.6090
# Epoch 158/250
# 9/8 [===============================] - 1s 160ms/step - loss: 1.0592 - acc: 0.9681 - val_loss: 2.7314 - val_acc: 0.6360
# Epoch 159/250
# 9/8 [===============================] - 1s 153ms/step - loss: 1.0573 - acc: 0.9594 - val_loss: 2.6091 - val_acc: 0.6288
# Epoch 160/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.0493 - acc: 0.9619 - val_loss: 2.6593 - val_acc: 0.6090
# Epoch 161/250
# 9/8 [===============================] - 1s 164ms/step - loss: 1.0459 - acc: 0.9644 - val_loss: 2.6788 - val_acc: 0.6306
# Epoch 162/250
# 9/8 [===============================] - 1s 149ms/step - loss: 1.0329 - acc: 0.9679 - val_loss: 2.7585 - val_acc: 0.6018
# Epoch 163/250
# 9/8 [===============================] - 2s 169ms/step - loss: 1.0669 - acc: 0.9621 - val_loss: 2.6811 - val_acc: 0.6072
# Epoch 164/250
# 9/8 [===============================] - 1s 159ms/step - loss: 0.9985 - acc: 0.9721 - val_loss: 2.6695 - val_acc: 0.6216
# Epoch 165/250
# 9/8 [===============================] - 1s 153ms/step - loss: 0.9997 - acc: 0.9741 - val_loss: 2.5110 - val_acc: 0.6396
# Epoch 166/250
# 9/8 [===============================] - 1s 153ms/step - loss: 1.0025 - acc: 0.9698 - val_loss: 2.6437 - val_acc: 0.6360
# Epoch 167/250
# 9/8 [===============================] - 1s 155ms/step - loss: 0.9754 - acc: 0.9748 - val_loss: 2.6840 - val_acc: 0.6108
# Epoch 168/250
# 9/8 [===============================] - 1s 157ms/step - loss: 0.9990 - acc: 0.9688 - val_loss: 2.7036 - val_acc: 0.6288
# Epoch 169/250
# 9/8 [===============================] - 1s 141ms/step - loss: 3.7993 - acc: 0.6058 - val_loss: 6.0077 - val_acc: 0.1766
# Epoch 170/250
# 9/8 [===============================] - 1s 147ms/step - loss: 3.8209 - acc: 0.5044 - val_loss: 4.3232 - val_acc: 0.3081
# Epoch 171/250
# 9/8 [===============================] - 1s 165ms/step - loss: 3.3162 - acc: 0.6090 - val_loss: 3.8803 - val_acc: 0.4667
# Epoch 172/250
# 9/8 [===============================] - 1s 163ms/step - loss: 2.5561 - acc: 0.7653 - val_loss: 3.7340 - val_acc: 0.4775
# Epoch 173/250
# 9/8 [===============================] - 1s 155ms/step - loss: 2.0720 - acc: 0.8096 - val_loss: 3.5638 - val_acc: 0.4811
# Epoch 174/250
# 9/8 [===============================] - 1s 153ms/step - loss: 1.8861 - acc: 0.8562 - val_loss: 3.4914 - val_acc: 0.5333
# Epoch 175/250
# 9/8 [===============================] - 1s 145ms/step - loss: 1.7695 - acc: 0.8864 - val_loss: 3.3965 - val_acc: 0.5459
# Epoch 176/250
# 9/8 [===============================] - 1s 146ms/step - loss: 1.6877 - acc: 0.8941 - val_loss: 3.3726 - val_acc: 0.5532
# Epoch 177/250
# 9/8 [===============================] - 1s 148ms/step - loss: 1.6775 - acc: 0.9110 - val_loss: 3.3512 - val_acc: 0.5568
# Epoch 178/250
# 9/8 [===============================] - 1s 162ms/step - loss: 1.6580 - acc: 0.9143 - val_loss: 3.2695 - val_acc: 0.5748
# Epoch 179/250
# 9/8 [===============================] - 1s 152ms/step - loss: 1.6706 - acc: 0.9088 - val_loss: 3.4138 - val_acc: 0.5351
# Epoch 180/250
# 9/8 [===============================] - 1s 144ms/step - loss: 1.5913 - acc: 0.9243 - val_loss: 3.2210 - val_acc: 0.5748
# Epoch 181/250
# 9/8 [===============================] - 1s 158ms/step - loss: 1.5744 - acc: 0.9228 - val_loss: 3.2143 - val_acc: 0.5820
# Epoch 182/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.5270 - acc: 0.9375 - val_loss: 3.1907 - val_acc: 0.5784
# Epoch 183/250
# 9/8 [===============================] - 1s 161ms/step - loss: 1.5505 - acc: 0.9429 - val_loss: 3.1607 - val_acc: 0.5856
# Epoch 184/250
# 9/8 [===============================] - 1s 149ms/step - loss: 1.5009 - acc: 0.9373 - val_loss: 3.2301 - val_acc: 0.5658
# Epoch 185/250
# 9/8 [===============================] - 1s 160ms/step - loss: 1.4962 - acc: 0.9417 - val_loss: 3.2406 - val_acc: 0.5892
# Epoch 186/250
# 9/8 [===============================] - 1s 150ms/step - loss: 1.4761 - acc: 0.9437 - val_loss: 3.2232 - val_acc: 0.5820
# Epoch 187/250
# 9/8 [===============================] - 1s 159ms/step - loss: 1.4702 - acc: 0.9417 - val_loss: 3.1046 - val_acc: 0.6018
# Epoch 188/250
# 9/8 [===============================] - 1s 159ms/step - loss: 1.4914 - acc: 0.9315 - val_loss: 3.1919 - val_acc: 0.5874
# Epoch 189/250
# 9/8 [===============================] - 1s 152ms/step - loss: 1.4719 - acc: 0.9447 - val_loss: 3.1733 - val_acc: 0.5910
# Epoch 190/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.4307 - acc: 0.9400 - val_loss: 3.1610 - val_acc: 0.6000
# Epoch 191/250
# 9/8 [===============================] - 1s 166ms/step - loss: 1.4763 - acc: 0.9456 - val_loss: 3.1490 - val_acc: 0.5910
# Epoch 192/250
# 9/8 [===============================] - 1s 161ms/step - loss: 1.4757 - acc: 0.9340 - val_loss: 3.0174 - val_acc: 0.6090
# Epoch 193/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.4176 - acc: 0.9452 - val_loss: 3.0781 - val_acc: 0.5874
# Epoch 194/250
# 9/8 [===============================] - 1s 143ms/step - loss: 1.3806 - acc: 0.9582 - val_loss: 2.9772 - val_acc: 0.6162
# Epoch 195/250
# 9/8 [===============================] - 1s 153ms/step - loss: 1.3829 - acc: 0.9539 - val_loss: 3.0426 - val_acc: 0.6054
# Epoch 196/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.4009 - acc: 0.9516 - val_loss: 3.0376 - val_acc: 0.6000
# Epoch 197/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.3702 - acc: 0.9512 - val_loss: 3.0341 - val_acc: 0.6000
# Epoch 198/250
# 9/8 [===============================] - 1s 157ms/step - loss: 1.3960 - acc: 0.9454 - val_loss: 3.1170 - val_acc: 0.6054
# Epoch 199/250
# 9/8 [===============================] - 1s 165ms/step - loss: 1.3707 - acc: 0.9497 - val_loss: 2.9166 - val_acc: 0.6000
# Epoch 200/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.3356 - acc: 0.9529 - val_loss: 2.9700 - val_acc: 0.5856
# Epoch 201/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.3947 - acc: 0.9429 - val_loss: 3.1186 - val_acc: 0.5838
# Epoch 202/250
# 9/8 [===============================] - 1s 161ms/step - loss: 1.3562 - acc: 0.9437 - val_loss: 3.0581 - val_acc: 0.5964
# Epoch 203/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.3688 - acc: 0.9437 - val_loss: 2.9311 - val_acc: 0.6036
# Epoch 204/250
# 9/8 [===============================] - 1s 152ms/step - loss: 1.3652 - acc: 0.9375 - val_loss: 3.0119 - val_acc: 0.5982
# Epoch 205/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.3831 - acc: 0.9445 - val_loss: 2.9175 - val_acc: 0.6162
# Epoch 206/250
# 9/8 [===============================] - 1s 164ms/step - loss: 1.3361 - acc: 0.9487 - val_loss: 2.9168 - val_acc: 0.5982
# Epoch 207/250
# 9/8 [===============================] - 1s 166ms/step - loss: 1.3583 - acc: 0.9419 - val_loss: 2.9430 - val_acc: 0.6144
# Epoch 208/250
# 9/8 [===============================] - 1s 150ms/step - loss: 1.3121 - acc: 0.9452 - val_loss: 3.0134 - val_acc: 0.5928
# Epoch 209/250
# 9/8 [===============================] - 1s 158ms/step - loss: 1.2982 - acc: 0.9557 - val_loss: 2.8578 - val_acc: 0.6288
# Epoch 210/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.3170 - acc: 0.9435 - val_loss: 2.9329 - val_acc: 0.6144
# Epoch 211/250
# 9/8 [===============================] - 1s 162ms/step - loss: 1.3183 - acc: 0.9516 - val_loss: 2.9894 - val_acc: 0.6000
# Epoch 212/250
# 9/8 [===============================] - 1s 160ms/step - loss: 1.2895 - acc: 0.9574 - val_loss: 2.8313 - val_acc: 0.6378
# Epoch 213/250
# 9/8 [===============================] - 1s 153ms/step - loss: 1.2928 - acc: 0.9566 - val_loss: 2.8303 - val_acc: 0.6162
# Epoch 214/250
# 9/8 [===============================] - 1s 163ms/step - loss: 1.2644 - acc: 0.9557 - val_loss: 2.8558 - val_acc: 0.6144
# Epoch 215/250
# 9/8 [===============================] - 1s 147ms/step - loss: 1.2665 - acc: 0.9576 - val_loss: 2.8658 - val_acc: 0.6036
# Epoch 216/250
# 9/8 [===============================] - 1s 162ms/step - loss: 1.2568 - acc: 0.9584 - val_loss: 2.8917 - val_acc: 0.6162
# Epoch 217/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.2750 - acc: 0.9534 - val_loss: 2.8705 - val_acc: 0.6270
# Epoch 218/250
# 9/8 [===============================] - 1s 157ms/step - loss: 1.2394 - acc: 0.9557 - val_loss: 2.7992 - val_acc: 0.6252
# Epoch 219/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.2528 - acc: 0.9601 - val_loss: 2.8832 - val_acc: 0.6054
# Epoch 220/250
# 9/8 [===============================] - 1s 162ms/step - loss: 1.2486 - acc: 0.9594 - val_loss: 2.8855 - val_acc: 0.6144
# Epoch 221/250
# 9/8 [===============================] - 1s 158ms/step - loss: 1.2398 - acc: 0.9532 - val_loss: 2.8223 - val_acc: 0.6126
# Epoch 222/250
# 9/8 [===============================] - 1s 165ms/step - loss: 1.2330 - acc: 0.9549 - val_loss: 2.8823 - val_acc: 0.5982
# Epoch 223/250
# 9/8 [===============================] - 1s 162ms/step - loss: 1.2484 - acc: 0.9472 - val_loss: 2.8298 - val_acc: 0.6162
# Epoch 224/250
# 9/8 [===============================] - 1s 160ms/step - loss: 1.2436 - acc: 0.9470 - val_loss: 2.8214 - val_acc: 0.6162
# Epoch 225/250
# 9/8 [===============================] - 1s 157ms/step - loss: 1.2238 - acc: 0.9557 - val_loss: 2.8087 - val_acc: 0.6162
# Epoch 226/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.2234 - acc: 0.9566 - val_loss: 2.8291 - val_acc: 0.6144
# Epoch 227/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.2519 - acc: 0.9516 - val_loss: 2.8512 - val_acc: 0.6072
# Epoch 228/250
# 9/8 [===============================] - 1s 163ms/step - loss: 1.2044 - acc: 0.9574 - val_loss: 2.7587 - val_acc: 0.6252
# Epoch 229/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.2279 - acc: 0.9532 - val_loss: 2.7810 - val_acc: 0.6270
# Epoch 230/250
# 9/8 [===============================] - 1s 150ms/step - loss: 1.2410 - acc: 0.9507 - val_loss: 2.8174 - val_acc: 0.6144
# Epoch 231/250
# 9/8 [===============================] - 1s 162ms/step - loss: 1.2182 - acc: 0.9452 - val_loss: 2.7626 - val_acc: 0.6126
# Epoch 232/250
# 9/8 [===============================] - 1s 152ms/step - loss: 1.1982 - acc: 0.9557 - val_loss: 2.8201 - val_acc: 0.6036
# Epoch 233/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.2096 - acc: 0.9549 - val_loss: 2.7534 - val_acc: 0.6198
# Epoch 234/250
# 9/8 [===============================] - 1s 161ms/step - loss: 1.1897 - acc: 0.9601 - val_loss: 2.7171 - val_acc: 0.6180
# Epoch 235/250
# 9/8 [===============================] - 1s 153ms/step - loss: 1.1744 - acc: 0.9547 - val_loss: 2.7758 - val_acc: 0.6126
# Epoch 236/250
# 9/8 [===============================] - 1s 162ms/step - loss: 1.2099 - acc: 0.9514 - val_loss: 2.8043 - val_acc: 0.6144
# Epoch 237/250
# 9/8 [===============================] - 1s 165ms/step - loss: 1.1941 - acc: 0.9522 - val_loss: 2.8517 - val_acc: 0.6072
# Epoch 238/250
# 9/8 [===============================] - 1s 160ms/step - loss: 1.2168 - acc: 0.9462 - val_loss: 2.8531 - val_acc: 0.5928
# Epoch 239/250
# 9/8 [===============================] - 1s 157ms/step - loss: 1.2212 - acc: 0.9462 - val_loss: 2.7137 - val_acc: 0.6090
# Epoch 240/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.1638 - acc: 0.9582 - val_loss: 2.7430 - val_acc: 0.6072
# Epoch 241/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.1884 - acc: 0.9566 - val_loss: 2.7638 - val_acc: 0.6162
# Epoch 242/250
# 9/8 [===============================] - 1s 159ms/step - loss: 1.2053 - acc: 0.9454 - val_loss: 2.7953 - val_acc: 0.6090
# Epoch 243/250
# 9/8 [===============================] - 1s 152ms/step - loss: 1.1979 - acc: 0.9470 - val_loss: 2.8229 - val_acc: 0.6108
# Epoch 244/250
# 9/8 [===============================] - 1s 159ms/step - loss: 1.1944 - acc: 0.9479 - val_loss: 2.9126 - val_acc: 0.5856
# Epoch 245/250
# 9/8 [===============================] - 1s 154ms/step - loss: 1.2142 - acc: 0.9429 - val_loss: 2.8376 - val_acc: 0.6126
# Epoch 246/250
# 9/8 [===============================] - 1s 157ms/step - loss: 1.2049 - acc: 0.9437 - val_loss: 2.7713 - val_acc: 0.6072
# Epoch 247/250
# 9/8 [===============================] - 1s 156ms/step - loss: 1.1509 - acc: 0.9626 - val_loss: 2.7626 - val_acc: 0.6198
# Epoch 248/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.1456 - acc: 0.9582 - val_loss: 2.7754 - val_acc: 0.6180
# Epoch 249/250
# 9/8 [===============================] - 1s 155ms/step - loss: 1.1758 - acc: 0.9514 - val_loss: 2.8917 - val_acc: 0.5874
# Epoch 250/250
# 9/8 [===============================] - 1s 160ms/step - loss: 1.2202 - acc: 0.9377 - val_loss: 2.7773 - val_acc: 0.6180

# %%
zoom_ranges = [0, 0.2, 0.35, 0.5, 0.7, [0.5, 1.0], [1.0, 1.5]]

# %%
zoom_ranges[4:]
# Out:
# [0.7, [0.5, 1.0], [1.0, 1.5]]

# %%
input_shape = (200, 200, 1)

learning_rate = 0.01

regularizer = regularizers.l2(0.01)
optimizer = optimizers.SGD(lr=learning_rate, decay=1e-7, momentum=0.9, nesterov=True)
# optimizer = optimizers.Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

net = KerasNeuralNetwork(input_shape, num_classes, regularizer=regularizer, optimizer=optimizer)
net.compile_model_6()

# %%
history = net.train(X_train, y_train, (X_val, y_val), epochs=100, batch_size=256, )

# %%
plot_history(history)

# %%
net.model.summary()

# %%
model_name = curr_date()

# %%
root_directory = '/home/stanislau/repository/machine-learning/brodatz/results/'
directory_name = root_directory + curr_date()

# %%
if not os.path.exists(directory_name):
    os.makedirs(directory_name)

# %%
model_json = net.model.to_json()
with open(directory_name + "/model.json", "w") as json_file:
    json_file.write(model_json)

# %%
utils.plot_model(net.model, to_file=directory_name + "/model.png", show_shapes=True)

# %%
accuracies = [net.accuracy(X_test, y_test) for X_test, y_test, _ in [(X_train, y_train, num_classes)] + test_list]

# %%
accuracies
